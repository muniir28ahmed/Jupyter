# %% [markdown]
# # Session 2 Exercises Notebook
#
# Each time you are given a programming exercise in session 2, you should complete it in this notebook. The sections are numbered and the instructions are given here in the notebook.

# %% [markdown]
# ## 2.6 Create, display and manipulate some simple variables in Python

# %% [markdown]
# ## First Python Code
# In the box below, write the Python code to print "Hello World" to the screen, and run it (Ctrl + Enter or with the Run button)

# %%
print("Welcome to BD2")
# Out:
# Welcome to BD2

# %% [markdown]
# ## Variables
# Create a variable called `kilos` and assign it the value 15. Then create a new variable called `pounds` and assign it a value that is the conversion from kilograms to pounds of the value in the `kilos` variable. Then print a sentence that tells us the weight in kilos and its equivalent in pounds. There are 2.2 pounds in a kilogram.

# %%
# Type your code here
kilos = 10
pounds = kilos / 2.2
print(f"The number of kilos is {kilos} and the number of pounds is {pounds}")
# Out:
# The number of kilos is 10 and the number of pounds is 4.545454545454545

# %% [markdown]
# ## 2.7 Data Types
# Print out the data types of both your variables, `kilos` and `pounds`,

# %%
# Type your code here
print(type(kilos))
print(type(pounds))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Next, create some variables and give them values of your own choosing. Experiment with different data types and the operators +,-,* and /. What happens if you add two strings, or multiply a string by a number?
#
# Use `str()` and `int()` or `float()` to change the data types - how do the results change? Use `type()` to see the data types of your results.

# %%
# Type your code here
kilometer = 1.0
meter = 1000
centimeter = "100000"
print(type(kilometer))
print(type(meter))
print(type(centimeter))
print(meter - kilometer)
#print(meter - centimeter) # does not work as integer and string can not be in an expression
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>
# 999.0

# %% [markdown]
# ## Calculate a volume
# Now write some code to calculate the volume of a box from its height, width and depth. Create three variables called `height`, `width`, and `depth` and assign a value to each. From those, create another variable called `volume`, which stores the result of multiplying the first three variables together. Print the result so that it looks like this example:
#
# The volume of a 3 by 4 by 5 box is 60

# %%
# Type your code here
hight = 3
width = 4
depth = 5
volume = hight*width*depth
print(f"The volume of a 3 by 4 by 5 box is {volume}")
# Out:
# The volume of a 3 by 4 by 5 box is 60

# %% [markdown]
# ## Processing user input
# Write some code to ask the user to enter a number in kilograms and then print the equivalent weight in pounds. Remember that the value they enter will come in as a string. Your program should cope with kilogram weights like 3.5.

# %%
# Type your code here
print("Enter a number of kilograms")
kilograms = input()
floatkilograms = float(kilograms)
pounds = floatkilograms * 2.2
print("Your number of kilograms in pounds is ", pounds)
# Out:
# Enter a number of kilograms
#  6
# Your number of kilograms in pounds is  13.200000000000001

# %% [markdown]
# # f-strings
# f-string syntax is `f"some text {variable} more text"`. Repeat the kilogram calculation code you used above, but this time use f-strings to print the result.

# %%
# Type your code here
print(f"The number of kilograms you put {floatkilograms} is {pounds} in pounds")
# Out:
# The number of kilograms you put 3.0 is 6.6000000000000005 in pounds
