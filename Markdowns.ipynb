# %% [markdown]
# # Markdowns
# This is about markdowns

# %% [markdown]
# ## Outcomes
# - Learn about markdowns
# - Install anoconda

# %% [markdown]
# __This makes writing Bold__

# %% [markdown]
# _This makes writing italic_

# %% [markdown]
# $ 2x+y=0 $

# %% [markdown]
# `text`
