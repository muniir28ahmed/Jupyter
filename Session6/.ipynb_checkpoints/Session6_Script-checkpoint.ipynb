# %% [markdown]
# # Session 6 Files and Remote Data
# ## Learning outcomes
#
# By the end of this session, you will be able to:
# - Read and write local files in a variety of formats
# - Use the requests library to access data over the internet
# - Extract part of a web page contents

# %% [markdown]
# # 6.3 Local File Processing -- RMD58
# ## 6.3a Os to navigate and access local storage

# %% [markdown]
# ## 6.3a Os to navigate and access local storage
# - Navigate
# - Search
# - Operating System specific path operations

# %%
import os

# %% [markdown]
# [To camera]
# Hi in this video we are going to have a look at the OS package which can be used to navigate and access your local storage.
# You can use it to search for specific files or directories and you can use it also to Confirm if a directory or a file either exists or is a file or a directory
#
# so without further ado let's see some examples
#
# ---
#
# [Screencast]
# so first of all we have to import the OS module and we do that like this
#
# ---
#
# then we can use OS all of its methods, functions and classes
#
# the first thing we might want to do is to see where we are executing this script or this file

# %%
os.getcwd()

# %% [markdown]
# to do that we use the get cwd method
#
# which is just get current working directory
#
# and if we execute that
#
# ---
#
# we get the full path to where this file is
#
# and because I'm executing this on an operating system that uses forward slash
# I get a path that I can directly use in my programme
# You might get different results on your machine.
#
# Okay, so what can we do with this information?

# %%
here = os.getcwd()
data_dir = here + "/" + 'test.json'
print(data_dir)

# %%
type(os.path.join(os.getcwd(),'test.json'))

# %%
type(os.getcwd())

# %%
os.path.join('/Users/saemundur/OneDrive - University of Stirling/UofS/Teaching/Insendi_ITNPBD2/upload_folders/session06','test.json')

# %% [markdown]
# We might perhaps need something in this directory called test.json that I wanted to access
#
# I could manipulate the path that i get from “get current working directory” by just adding the forward slash and the string “test.json” to the path that I got from that method
#
# which works
#
# ---
#
# but what if I wanted to execute the same script on another computer or elsewhere on my computer
#
# Somewhere I don't know the path structure or the operating system beforehand?
#
# OS implements the path module which is used to manipulate and navigate your local storage and Takes care of all of that for you
#
# ---
#
# so to add or extend the path with a new directory we use the join method which does the same thing as our manual method above
#
# ---
#
# as you can see.
#
# but here we don't have to assume forward or backslash and we don't have to assume the current working directory either
#
# Best practice coding makes as few assumptions as possible
# Because, the more generalised we can make our code the better.

# %%
# What would happend if you tried to open this
"nonsense/path/to/non-existing/file"

# %%
print(os.path.exists("nonsense/path/to/non-existing/file"))
print(os.path.exists(os.path.join(os.getcwd(),'test.json')))

# %% [markdown]
# As for example when we are manually navigating through File Explorer
#
# we know what's there because we see it there.
#
# however we can't assume that the program we are writing will always be executed with the same file structure
#
# And we also can't be sure that what we're trying to access actually exists
#
# Like in this example nonsense path
#
# so there's another function in the path module simply called “exists”
#
# ---
#
# Which cheques if the full path exists whatever it might be a file or a directory
#
# ---
#
# And as you can see the path to current working directory with the added test Jason exists
#
# It is a good thing we can cheque
#
# because if we try to access something that doesn’t exist we would get an exception and our program would fail
#
# And it also matters if what we're trying to access is a file or a directory

# %%
the_path = os.path.join(os.getcwd(),'test.json')
print(os.path.isdir(the_path))
print(os.path.isfile(the_path))

# %% [markdown]
# if we want to know if the path we have points too a directory or a file we have two functions:
#
# isdir and isfile
#
# that cheque if the path is either a directory or a file
#
# I think you can guess which one is which
#
# ---
#
#
# testing both on our test.json we see that isdir will return false and isfile will return true
#
# The path module also implements a couple of other handy functions

# %%
os.path.dirname('/home/saemi/library/school/data/insendi.html')

# %%
print(os.path.basename('/home/saemi/library/school/data/insendi.html'))
print(os.path.basename(os.getcwd()))

# %% [markdown]
# to inspect paths for example the dirname function
#
# ---
#
# will give you The directory's name of a string that represents a path
#
# and the path doesn't need to exist at all actually
#
# ---
#
# See if we change the string to the nonsense path we had before
#
# "nonsense/path/to/non-existing/file"
#
# and execute again.
#
# ---
#
# it still works
#
# we still get everything except the last part
#
# the opposite of dirname is the base name function
#
# ---
#
# which will give you the last part of a path
#
# so, let's try that on the same path string as before and also on our current working directory
#
# ---
#
# and as you can see, we got the HTML file and our current directory without the full path to it.
#
# The last thing I want to show you from the OS module is the walk function

# %%
for base, dirs, fids in os.walk(os.getcwd()):
    print(base)
    print(dirs)
    print(fids)

# %% [markdown]
# It's an iteration function which, like the name implies, walks from a specific path point and recursively through all sub directories, sub-sub directories and so on
#
# listing all directories and files on its way.
#
# For every directory that it descends into, it will produce the path or base name, a list of subdirectories, and a list of files.
#
# Let’s try it with our current working directory, Which shouldn't contain much
#
# ---
#
# but you see first the name of the working directory
#
# followed by a list of a single sub folder
#
# and then every file contained within the current directory
#
# then it entered the sub folder and listed the same for that
#
#
# Now you should go and try out some of the exercises for this session where you will be able to see how the OS module can navigate your own local storage

# %% [markdown]
# # 6.3b File handling -- RMD59

# %% [markdown]
# # File handling
# - Reading and writing
# - open
# - with as

# %% [markdown]
# Hi, in this video we will look at how we can use Python to read and write to files on your local storage
# for that we will use the open function and you will also be introduced to the with-as function.
#
# So, let's just get started

# %%
import os

# %% [markdown]
# First we'll import the OS module as we'll use one of it's functions to check if the file we will be working with exists or not.
#
# ---

# %%
print(os.path.exists('test_data.txt'))

# %%
fid = open('test_data.txt','w')
print(fid)

# %%
fid.write('This is the first line, because the w (write) flag overwrites anything that was here before\n')
fid.write('This is the second line\n')

# %%
fid.close()

# %%
print(os.path.exists('test_data.txt'))

# %% [markdown]
# In this demonstration we're going to be working with a single file:
#
# test, underscore, data, dot txt
# Before we do anything, we'll check if it exists.
#
# ---
#
# and as you can see, it doesn't.
# Which is fine, since our first task will be to write into it
#
# ---
#
# For Python to be able to work with contents of files it has to open them, for that purpose we use the open function
#
# and for our first example we're going to write a couple of lines into the file
#
# The open function requires, at the bare minimum, the name of the file that you want to open And if that's the only argument then Python will assume that you're reading the file
# to be able to write to a file we have to specify the mode argument which will be a single character flag indicating what we want to do
# The write flag is a W
#
# ---
#
# the open function returns a file object Which has a few methods
#
# ---
#
# one of which is called write
# and by calling it with some strings as arguments we've written to the file.
#
# ---
#
# after we've written all that we want to the file
#
# ---
#
# we have to close it
#
# for that purpose we call the close method on the file object itself
#
# ---
#
# Strictly speaking, it is not absolutely necessary to close the file
#
# Best case scenario, the interpreter will close it for you when you stop using it.
# But since the interpreter doesn't know when that happens, until you maybe overwrite the varible
#
# it might not happen until you shutdown the python kernel
#
# additionally, in some instances, Python won't actually write to the file until it is closed,
#
# keeping everything we wrote in buffer memory
#
# But, okay, we have now closed the file. Does it exist?
#
# ---
#
# yes it does
#
# so the W flag will not only write to a file but it will also create it if it doesn't exist
#
# however, there's one caveat in using that flag and that is, if a file exists the W flag will make Python overwrite whatever was in the file before, so it will start with a clean slate every time you open a file like this
#
# to be able to add to files we have to use the A flag which stands for append,

# %%
with open('test_data.txt','a') as fid:
    fid.write('This will be added at the end of the file because we used the a (append) flag')

# %% [markdown]
# here we open the same file with the append flag and write a single line into it
#
# ---
#
# you've probably noticed that in this cell we didn't explicitly close the file
#
# but we've encompassed the open function in a with argument
#
# a with clause will take care of that for you
#
# what that essentially does is it creates the variable after the keyword "AS" which contains the file object
#
# and then when the script exits the body of the with statement
#
# it will call the close method behind the curtains
#
# This is the preferred method of working with opening and closing files
#
# it saves you from having to think about garbage collection and unnecessary memory use

# %%
with open('test_data.txt','r') as fid:
    text = fid.read()
print(text)

# %% [markdown]
# so if we continue with our example we can open the test data file to be read with the R flag
#
# The file object has a couple of methods to explore the content of the file
# The first one is just read, which reads the whole document into a single string like this
#
# ---
#
# For a large file that might not be the best approach.

# %%
with open('test_data.txt','r') as fid:
    print(fid.readline())
    print(fid.readline())

# %% [markdown]
# We can also read a single line at a time like here.
#
# ---
#
# and you see the first two lines we wrote are returned
# And the file object keeps track of its location in the file.
#
# So if you want the first line again you’ll either have to close and open the file again or use the seek method
#
# which I’ll allow you to read-up-on, yourselves
#
# Now we wouldn't want to call this method for every line in the file
#
# because in most cases we don't know how many lines in a file there are
#
# but we're in luck we don't have to

# %%
with open('test_data.txt','r') as fid:
    print('first line: ',fid.readline())
    for line in fid:
        print('line: ',line)

# %%
with open('test_data.txt','r') as fid:
    all_lines = fid.readlines()
display(all_lines)

# %% [markdown]
# because if we treat the file objects as an iterator like here
# The for loop will just feed us everything that's in the file line by line
#
# ---
#
# And notice that the first line was only printed once and not as part of the for loop because the file object is keeping track
#
# In big data, when files are huge, bite sized iterations similar to this are preferred,
#
# treating data as streams and dealing with it for example line by line.
#
# However if you have enough memory and are just going to treat the raw content of the file line by line in a list.
#
# You might as well use the plural form of the read line method, readlines
#
# ---
#
# Which returns the whole file in a list of strings like this.
#
# ---
#
#
# Okay, now you should know enough about file handling to try out your knowledge in an exercise.
#
# So, off you go and don’t forget to look up the seek method

# %% [markdown]
# ## 6.4a Parse CSV file demonstration
# ### RMD61

# %% [markdown]
# # Parse CSV file
# - Read
# - Write

# %% [markdown]
# Hi, in this video we are going to look at how we can use Python to read and write CSV files.
# So let's not hang around and get right to it

# %%
import csv

# %% [markdown]
# first of all we have to import the CSV module
#
# ---
#
# and now we can use all of its methods and functions

# %%
dummy_data = [[1, 2, 3, "a", "a,b"],
              [4, 5, 6, "b", "c"]]
column_names = ['col_1','col_2','col_3','col_4','col_5']

# %%
with open('test.csv','w',newline='') as csv_fid:
    csv_writer = csv.writer(csv_fid, delimiter=',',
                            quotechar='"')
    csv_writer.writerow(column_names)
    csv_writer.writerows(dummy_data)

# %%
with open('test.csv','w',newline='') as csv_fid:
    csv_writer = csv.writer(csv_fid, delimiter=',',
                            quotechar='"')
    for row in [column_names]+dummy_data:
        csv_writer.writerow(row)

# %% [markdown]
# so let's start with writing a CSV data to a CSV file
# here we have the dummy data in one variable and column names in the other
#
# ---
#
# and we use now the familiar way of opening a file with the W flag but you notice also that we have the newline Argument which is required when we use the CSV writer class
#
# - we start by creating the writer object
# - where the first argument is the file object that we want to write into,
# - then we Define the separator or delimiter,
# - and the character which will be used for quotations
#
# * for the column names we write a single row with writerow
# * and then because the dummy data is in a 2 dimensional list
#   - we can use the plural of that same method writerows
#
# Obviously there's no output from running this cell
#
# ---
#
# because we didn't print anything except into the file
#
# you can open up the file test.CSV to look at its contents for yourselves if you’ve been following along on your own machine.
#
# this example shows the functionality when the data is in sequences like arrays and lists
# so, to record the header row you have to either add it as the first row of the data or write it explicitly to the file
#
# you could potentially also iterate over the dummy data and add each row one by one like the header row.
# like this
#
# ---
#
# But it might be a bit slower for larger datasets

# %%
dummy_data = [{'col_1':1,'col_2':4,'col_3':7,'col_4':10,'col_5':13,'bin':"an item that won't be written"},
              {'col_1':2,'col_2':5,'col_3':8,'col_4':11,'col_5':14,'trash':"This won't be written"},
              {'col_1':3,'col_2':6,'col_3':9,'col_4':12,'col_5':15}]
fieldnames = ['col_1','col_2','col_3','col_4','col_5']

# %%
with open('test_dictionary.csv','w',newline='') as csv_fid:
    csv_writer = csv.DictWriter(csv_fid,
                               delimiter=',', quotechar='"',
                                extrasaction='ignore',
                               fieldnames=fieldnames)
    csv_writer.writeheader()
    csv_writer.writerows(dummy_data)

# %% [markdown]
# if your data has a structure like dictionaries let's say a list of dictionaries like here
#
# ---
#
# you can use the dict writer function instead
#
# ---
#
# Then you initiate the writer object in line 2
#
# with field names or column names as well so writing the header row is an explicit function you call in line 6
#
# Also notice the data dictionaries that they're not all the same size and don't at all have the same fields so if you include the argument “extrasaction” as “ignore” it will only write the field names that you give it
#
#
# ---
#
#
# if you don't ignore it, then you’ll get an exception
#
# so that's the two ways of using the CSV module to write CSV data, now how about reading that data?

# %%
with open('test.csv','r',newline='') as csv_fid:
    csv_reader = csv.reader(csv_fid, delimiter=",", quotechar='"')
    for row in csv_reader:
        print(row)

# %%
with open('test.csv','r',newline='') as csv_fid:
    csv_reader = csv.reader(csv_fid, delimiter=",", quotechar='"')
    data = [row for row in csv_reader]
display(data)

# %% [markdown]
# like we had the writer and dict writer classes we have the equivalent reader and dict reader classes
#
# As you’ve probably guessed the reader will iterate each row as a list and we can iterate through it like we do when iterating lines in a file.
#
# ---
#
# The difference is that the csv reader has already processed the row into a list according to our delimiter argument.
# It also removes any quote character that is present in the file as it is irrelevant to our data
#
# ---
#
# As for many other for loop functionality, you can also code this as a list comprehension to store the data in a 2-d list right from the reader.
#
# ---

# %%
with open('test.csv','r',newline='') as csv_fid:
    csv_reader = csv.DictReader(csv_fid, delimiter=",", quotechar='"')
    print(csv_reader.fieldnames)
    for row in csv_reader:
        print(row)

# %% [markdown]
# The dict reader on the other hand iterates over the CSV file as a series of dictionaries where the first line of the CSV file defines the field names or column names
# and this reader therefore also defines the method field names as you see in line 3
#
# ---
#
# and it's not just any dictionary that is returned they are ordered dictionaries so they come in the order as they were in the file
#
# so, that's it for CSV reading and writing combining what you've learnt in this video with your other knowledge you should now be quite capable of attempting the exercise

# %% [markdown]
# # 6.4b Parse JSON file demonstration -- RMD62

# %% [markdown]
# # Parse JSON file
# - Create
# - Read
# - Write

# %%
import json

# %% [markdown]
# [To Camera]
# Hi in this video we are going to explore how we can use Python to easily parse and create JSON data .
# And this is particularly useful since JSON data is quite common for online sources
# so let's not Delay any further and open our notebooks
#
# [Screencast]
# as with any other non built in packets we have to import the JSON module first before we can use its functionality so here's that
#
# ---

# %%
dummy_data = [{'col_1':1,'col_2':4,'col_3':7,'col_4':10,'col_5':13},
              {'col_1':2,'col_2':5,'col_3':8,'col_4':11,'col_5':14},
              {'col_1':3,'col_2':6,'col_3':9,'col_4':12,'col_5':15}]
json_obj = json.dumps(dummy_data,indent=1)
print(type(json_obj))

# %%
print(json_obj)

# %% [markdown]
# the easiest way of converting Python data or variables into Jason objects
#
# is to use the Jason dumps method
#
# it converts the variable, in this instance a list of dictionaries, into a single string Jason object
#
# ---
#
#
# and if we then print the json object,
#
# ---
#
# you see every string in the dictionaries has been quoted and it basically follows the same structure as the Python data
#
# you need to remember though
#
# the Jason module can only convert the basic types: strings, integers, floats, boolean and none

# %%
with open('test.json','w') as json_fid:
    json.dump(dummy_data,json_fid)

# %% [markdown]
# Now if you want to save your Jason data into a file
#
# the easiest way is to use the Jason dump function, without the S.
#
# and you just pass the data and the opened file object as the arguments like this
#
# then, when you want to open it and read it again you can use the load functionality of the Jason module

# %%
with open('test.json','r') as json_fid:
    read_data = json.load(json_fid)

# %%
display(read_data)
display(type(read_data))

# %% [markdown]
# and what you do is just simply open a file object and pass that along to the load function like here
#
# ---
#
# and when you display the results
#
# ---
#
# you see it has conveniently already parsed the whole document into a list of dictionaries
#
# without us ever having to use any conversions like integers or floats
#
# or having to evaluate any of the lines it just does it for us
#
# but sometimes you encounter bigger files or a stream of strings, where each one of them is a Jason object

# %%
with open('test_rows.json','r') as json_fid:
    for row in json_fid:
        print(json.loads(row))

# %% [markdown]
#  then you might want to use the loads function which basically means |load string|
#
# and that parses whatever string you pass it into an equivalent Python variable like here
#
# ---
#
# so, instead of a list of dictionaries we now have just three separate dictionaries .
#
# now you have the basics of reading and writing Jason files into Python
#
# And I think you are ready to go and have some fun yourselves in the exercises

# %% [markdown]
# # 6.5 The ElementTree XML API demonstration -- RMD64

# %% [markdown]
# # The ElementTree XML
# - XML trees
# - Load
# - Manipulate
# - Write

# %%
import xml.etree.ElementTree as ET

# %% [markdown]
# [To Camera]
# Hi, in this video we're going to look at parsing XML data in and out of Python .
# And we're going to use the element tree API to accomplish that and have a look at some functionality to traverse and manipulate XML trees .
#
#
# ---
#
#
# first of all we have to import the element tree which is part of the XML module and because it's tedious to always write element tree we shortened that as capital ET

# %% [raw]
# <?xml version="1.0" encoding="UTF-8"?>
# <RESTAURANT>
# <section>
#     <title>Starters</title>
#     <items>
#         <item priority="1">
#             <name>Bread sticks</name>
#             <price>0.30</price>
#             <description>Something to fill you up while you wait.</description>
#         </item>
#         <item priority="10">
#             <name>Salad</name>
#             <price>5.40</price>
#             <description>A very fancy salad.</description>
#         </item>
#         <item priority="11">
#             <name>Soup</name>
#             <price>2.30</price>
#             <description>Leek and onion soup</description>
#         </item>
#     </items>
# </section>
# <section>
#     <title>Mains</title>
#     <items>
#         <item vegan="0">
#             <name>Burger</name>
#             <price>8.30</price>
#             <description>Just beef and a bun</description>
#         </item>
#         <item vegan="0">
#             <name>Steak</name>
#             <price>12.40</price>
#             <description>Some mammal meat</description>
#         </item>
#         <item vegan="1">
#             <name>Pasta</name>
#             <price>6.40</price>
#             <description>Italian? Maybe.</description>
#         </item>
#     </items>
# </section>
# <section>
#     <title>Desserts</title>
#     <items>
#         <item cold="yes">
#             <name>Ice cream</name>
#             <price>3.60</price>
#             <description>It's cold, okay?</description>
#         </item>
#         <item cold="maybe">
#             <name>Cake</name>
#             <price>1.50</price>
#             <description>Whatever was reduced in Co-op</description>
#         </item>
#     </items>
# </section>
# </RESTAURANT>

# %% [markdown]
# so this is the XML data that we are going to play with
# you can either copy paste it from here into a separate XML file but be sure to call it the same name as we use in the following cells
# or you should be able to download the file from the website
# the data is a restaurant menu with three sections:
# - starters,
# - mains,
# - and desserts
# each section has a title and a list of items
#
# so how do we get this into Python?

# %%
tree = ET.parse('small_menu.xml')
print(tree)
print(tree.getroot())

# %%
with open('small_menu.xml','r') as fid:
    tree = ET.ElementTree(element = ET.fromstring(fid.read()))
    
print(tree)
print(tree.getroot())

# %% [markdown]
# We use the parse function from the ET module
# I will just give it the filename and if the file is well formed nothing special will happen
#
# ---
#
# it will just create a tree of which there is a single root element which we can get with “get root”
# as you see here
#
# ---
#
# you can also parse the file by opening it and creating an element tree where the element argument is the root of the tree like here
#
# ---
#
# it produces the same thing as before

# %%
root = tree.getroot()
print(root.tag)
print(root.attrib)
print(root.text)

# %% [markdown]
# So let's see what the tree contains
#
# each node in the XML tree is an element
#
# and each element has a Tag which you can see with the tag attribute and it is the same as the tag in XML files
#
# you can access each elements attributes with the dot attrib attribute
#
# and it might contain some text, which is accessed with the text attribute
#
#
# so these are the three primary attributes of elements that you have to know of
#
# there are others, but they are not as important for now
#
# and I will trust you to read up on it yourselves if or when you need to.
#
# but back to our tree,
#
# ---
#
# the root's element's tag is restaurant
#
# restaurant doesn't have any attributes
#
# and the text is a white space or nothing
#
# so, let's explore the tree further

# %%
for child in root:
    print(child.tag)

# %% [markdown]
# each element implements an iterator
#
# which we can use directly in a for loop like here
#
# ---
#
# which, as you see, iterates every child node of that element
#
# so our root element, the restaurant has three children elements,

# %%
for text in root.itertext():
    print(text)

# %% [markdown]
# we can also iterate only the text in the entire document for that we use the iter text function
#
# and as you can see
#
# ---
#
# it just prints everything
#
# as well as the white spaces and new lines
#
# basically, everything that's outside of tags in an XML document

# %%
for descendant in root.iter():
    print(descendant.tag,descendant.attrib,descendant.text)

# %% [markdown]
# now to iterate over every single node in the XML tree
#
# we can use root dot iter
#
# without an argument
# and as you can see
#
# ---
#
# the tag, attributeS and text of every single node gets printed to the screen
#
# we can use this iter function to filter out certain elements

# %%
for descendant in root.iter():
    vegan = descendant.get("vegan",None)
    if vegan is not None:
        for child in descendant:
            print(f'{child.tag}: {child.text}')

# %% [markdown]
# for example if we wanted only elements that had vegan as one of its attributes we could do this
#
# using the get method on an element acts like the get methods on a dictionary, the dictionary in this case is the attribute dictionary
#
# as you saw before when we printed out all the tags attributes and text the attributes were in a dictionary
#
# ---
#
# So here we have all the mains because
#
# they have the attribute vegan although they might not be vegan

# %%
for food_name in root.iter('name'):
    print(food_name.text)

# %% [markdown]
# you can also pass the Iter function an argument which is kind of the keyword search
#
# if you pass it just a simple string it will iterate the elements with that tag
#
# so for example if we pass it name as the argument
#
# ---
#
# it will find all the elements that have name as its tag
#
# and this is case sensitive so it matters if we capitalise or not
#
# so, we now have the basics of finding data in XML documents what about changing them and adding to them

# %% [raw]
# <item>
#    <name></name>
#    <price></price>
#    <description></description>
# </item>

# %% [markdown]
# so let's say for example we have a new main on our menu and we want to add that to the XML document
# If you look at the XML document you’ll see that each course is an item element which contains three children: name, price and description

# %%
new_main = {'name':'Fish', 'price':'9.32', 'description': 'Catch of the day'}

# %%
new_element = ET.Element('item')

# %%
for key,val in new_main.items():
    _element = ET.Element(key)
    _element.text = val
    new_element.append(_element)

# %%
for section in root.findall('section'):
    if section.find('title').text == 'Mains':
        section[1].append(new_element)

# %% [markdown]
# Here we have Our new course in a dictionary and we will build the item element from that.
#
# ---
#
# So, we start by initiating an Element with the tag “item”
#
# ---
#
# Then for each key, value pair in the dictionary
# - we make a new element
# - and pass the key as its tag
# - and then set the text as the value
#
# And the way to associate one element as another’s child is to use the append method like in line 4
#
# ---
#
# These few lines of code have created an item element which in itself is a tree.
#
# Now we just have to plant it in the correct location in our restaurant tree.
#
# ---
#
# For that we can use the findall function which returns a list of elements that match the argument.
# In this case the simple term “section” which will look for tag names that match
#
# The ElementTree module can perform very simple Xpath searches but other modules handle that better and I’ll leave it up to you to look that up.
#
# So, back to the action.
#
# ---
#
# Iterating over the sections we use the find function which is nearly the same as findall, except it returns only the first instance found and not the list.
#
# We use our knowledge here in line 2 that there is only one title tag in each section and if the title is Mains then we’re in the correct section.
#
# And again, since we know that the second element of a section is the list of items we can use indexing to select what element to append to in line 3.

# %%
ET.dump(root)

# %% [markdown]
# And by using the dump method of ET we can see that our fish is where it should be.
# Although not as pretty formatted as the rest of the document.
#
# Similarly as adding elements to a tree we can remove them with the remove method.

# %%
for items in root.findall('section/items'):
    for item in items.findall('item'):
        if float(item.find('price').text) < 2:
            items.remove(item)

# %% [markdown]
# Let’s say for example that we wanted to remove all menu items that are priced lower than 2
#
# Then we use findall again
#
# but now we’re searching for any items element that has section as parent which is denoted with a folder-like hirearcy: "section-slash-items"
#
# and then we’ll have to iterate over each of their children to see if any of the prices are less than 2.
#
# If they are then we use the remove function in line 4.
#
# And here’s why we need to find the items lists because we can only remove from immediate parent element and not from the whole tree or grandparent.

# %%
ET.dump(root)

# %% [markdown]
# So if we now look at how the XML document looks we see that there are no items priced lower than 2 anymore

# %%
#tree.write('altered_menu.xml')
import json
import xml.etree.ElementTree as ET

# %% [markdown]
# And since we’re now finished messing with it we can then use the tree’s write method to simply save the tree to a file simply like this.
#
# Now, you go and have a look at that and attempt the exercises

# %% [markdown]
# # 6.6 Remote data -- RMD66

# %% [markdown]
# # Remote data
# ## REST interfaces demonstration
# - Web interfaces
# - Download
# - Scrape

# %%
import requests
from urllib.parse import urljoin

# %% [markdown]
# Hi, in this video we will look at how we can write a simple Python program that fetches data from the internet and interacts with REST services.
#
# ---
#
# First we'll have to import the packages we will need.
#
# ---
#
# Requests gives our script the ability to communicate through web protocols and the urljoin module from urllib does the same thing for urls as path join does for paths on your local storage. That is, stitches multiple partial urls together to form a single whole one.
# So, let's see what we can do with requests

# %%
url="https://www.vam.ac.uk/api/json/museumobject/search?q=Turner"

# %%
resp = requests.get(url)

# %%
print(resp.status_code)
# Out:
# 200

# %%
url="https://www.vam.ac.uk/api/json/museumobject/search"
resp = requests.get(url,{'q':'Turner'})
print(resp.url)
print(resp.status_code)
# Out:
# https://www.vam.ac.uk/api/json/museumobject/search?q=Turner
# 200

# %% [markdown]
# Here we have a url for a search of the Victoria and Albert museum
# If we examine the url a bit, you’ll see that it passes an argument to the service.
# The syntax is that everything after a question mark are arguments.
# In this case there is a named argument Q with the value Turner.
#
# ---
#
# by using the get method of requests we can simply ask the service at the other end of that url to send us a response.
#
# ---
#
# And we can check that the status of the response is 200,
#
# ---
#
# which means success.
#
# Now, obviously if we were conducting a single search with a single argument,
#
# this might be fine.
#
# However, the get method of the requests module can build such urls for us.
#
# ---
#
# Like here,
#
# ---
#
# we’ve omitted the argument from the url string and instead we’ve passed the argument as part of a dictionary argument to the get method.
#
# And, as you can see, the url ends up being exactly the same and we still get a successful response.
#
# The same applies to the post method of requests but instead of building a url it sends the arguments as posted data. You will have to check with the web services you will be interacting with
#
# whether they use or even support the post method. Not all do and some will require it.
#
# Now, back to our request. How do we get to the actual response?

# %%
print(resp.content)
# Out:
# b'{\n    "meta": {\n        "clusters": [],\n        "cluster_counts": {},\n        "result_count": 17913,\n        "group_details": []\n    },\n    "records": [\n        {\n            "fields": {\n                "rights": 3,\n                "museum_number_token": "11601901",\n                "artist": "J.M.W. Turner",\n                "sys_updated": "",\n                "latitude": "",\n                "title": "Pembury Mill, near Tunbridge Wells",\n                "collection_code": "PDP",\n                "object_number": "O1042104",\n                "longitude": "",\n                "location": "Prints & Drawings Study Room, level H, case WD, shelf 55",\n                "slug": "pembury-mill-near-tunbridge-wells-watercolour",\n                "object": "Watercolour",\n                "museum_number": "1160-1901",\n                "place": "",\n                "primary_image_id": "2006BB5716",\n                "date_text": "Early 19th century"\n            },\n            "pk": 42953,\n            "model": "collection.museumobject"\n        },\n        {\n            "fields": {\n                "rights": 3,\n                "museum_number_token": "17231900",\n                "artist": "J.M.W. Turner",\n                "sys_updated": "",\n                "latitude": "",\n                "title": "Boats with Fishermen",\n                "collection_code": "PDP",\n                "object_number": "O1041828",\n                "longitude": "",\n                "location": "Prints & Drawings Study Room, level H, case WD, shelf 55",\n                "slug": "boats-with-fishermen-watercolour",\n                "object": "Watercolour",\n                "museum_number": "1723-1900",\n                "place": "",\n                "primary_image_id": "2006BB5721"\n            },\n            "pk": 39744,\n            "model": "collection.museumobject"\n        },\n        {\n            "fields": {\n                "rights": 3,\n                "museum_number_token": "s44422009",\n                "artist": "Turner, Charles",\n                "sys_updated": "",\n                "latitude": "",\n                "title": "H Beard Print Collection",\n                "collection_code": "T&P",\n                "object_number": "O230719",\n                "longitude": "",\n                "location": "In Storage",\n                "slug": "h-beard-print-collection-print",\n                "object": "Print",\n                "museum_number": "S.4442-2009",\n                "place": "London",\n                "primary_image_id": "2010EF8439",\n                "date_text": "20th May 1822"\n            },\n            "pk": 17324,\n            "model": "collection.museumobject"\n        },\n        {\n            "fields": {\n                "rights": 3,\n                "museum_number_token": "198b1889",\n                "artist": "Richard Redgrave",\n                "sys_updated": "",\n                "latitude": "",\n                "title": "Portrait of J. M. W. Turner",\n                "collection_code": "PDP",\n                "object_number": "O1105098",\n                "longitude": "",\n                "location": "Prints & Drawings Study Room, level H, case PD, shelf 307",\n                "slug": "portrait-of-j-m-w-drawing",\n                "object": "Drawing",\n                "museum_number": "198B-1889",\n                "place": "Britain",\n                "primary_image_id": "2017KE4979",\n                "date_text": "mid 19th century"\n            },\n            "pk": 17329,\n            "model": "collection.museumobject"\n        },\n        {\n            "fields": {\n                "rights": 3,\n                "museum_number_token": "cai516",\n                "artist": "Turner",\n                "sys_updated": "",\n                "latitude": "",\n                "title": "Liber Studiorum",\n                "collection_code": "PDP",\n                "object_number": "O517174",\n                "longitude": "",\n      ...

# %% [markdown]
# The Python response object has a number of methods to utilise for that.
#
# First of, is the content attribute that gives us the content in the form that the service defined it.
#
# ---
#
# As you can see by the B in front of the quotation mark it is in bytes rather than text or unicode.
#
# Notice also that it doesn’t look like it is html, right? More like the json format.
#
# So how do we convert it into something we can work with in Python? The json module can load text, not bytes.

# %%
print(type(resp.content))
print(type(resp.text))
# Out:
# <class 'bytes'>
# <class 'str'>

# %% [markdown]
# We can get the text equivalent of the content by calling the text attribute of the response
#
# ---
#
# and as you can see the type from that is always string.

# %%
import json
json.loads(resp.text)
# Out:
# {'meta': {'clusters': [],
#   'cluster_counts': {},
#   'result_count': 17913,
#   'group_details': []},
#  'records': [{'fields': {'rights': 3,
#     'museum_number_token': '11601901',
#     'artist': 'J.M.W. Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Pembury Mill, near Tunbridge Wells',
#     'collection_code': 'PDP',
#     'object_number': 'O1042104',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level H, case WD, shelf 55',
#     'slug': 'pembury-mill-near-tunbridge-wells-watercolour',
#     'object': 'Watercolour',
#     'museum_number': '1160-1901',
#     'place': '',
#     'primary_image_id': '2006BB5716',
#     'date_text': 'Early 19th century'},
#    'pk': 42953,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': '17231900',
#     'artist': 'J.M.W. Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Boats with Fishermen',
#     'collection_code': 'PDP',
#     'object_number': 'O1041828',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level H, case WD, shelf 55',
#     'slug': 'boats-with-fishermen-watercolour',
#     'object': 'Watercolour',
#     'museum_number': '1723-1900',
#     'place': '',
#     'primary_image_id': '2006BB5721'},
#    'pk': 39744,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': 's44422009',
#     'artist': 'Turner, Charles',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'H Beard Print Collection',
#     'collection_code': 'T&P',
#     'object_number': 'O230719',
#     'longitude': '',
#     'location': 'In Storage',
#     'slug': 'h-beard-print-collection-print',
#     'object': 'Print',
#     'museum_number': 'S.4442-2009',
#     'place': 'London',
#     'primary_image_id': '2010EF8439',
#     'date_text': '20th May 1822'},
#    'pk': 17324,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': '198b1889',
#     'artist': 'Richard Redgrave',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Portrait of J. M. W. Turner',
#     'collection_code': 'PDP',
#     'object_number': 'O1105098',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level H, case PD, shelf 307',
#     'slug': 'portrait-of-j-m-w-drawing',
#     'object': 'Drawing',
#     'museum_number': '198B-1889',
#     'place': 'Britain',
#     'primary_image_id': '2017KE4979',
#     'date_text': 'mid 19th century'},
#    'pk': 17329,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': 'cai516',
#     'artist': 'Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Liber Studiorum',
#     'collection_code': 'PDP',
#     'object_number': 'O517174',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level C, case IONIDES, shelf 9',
#     'slug': 'liber-studiorum-print',
#     'object': 'Print',
#     'museum_number': 'CAI.516',
#     'place': 'Britain',
#     'primary_image_id': '2017JR8330',
#     'date_text': 'ca. early 19th century'},
#    'pk': 17460,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': 'cai523',
#     'artist': 'Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Liber Studiorum',
#     'collection_code': 'PDP',
#     'object_number': 'O517167',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level C, case IONIDES, shelf 9',
#     'slug': 'liber-studiorum-print',
#     'object': 'Print',
#     'museum_number': 'CAI.523',
#     'place': 'Britain',
#     'primary_image_id': '2017JR8441',
#     'date_text': 'ca. early 19th century'},
#    'pk': 6722,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': 'cai525',
#     'artist': 'Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Liber Studiorum',
#     'collection_code': 'PDP',
#     'object_number': 'O517165',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level C, case IONIDES, shelf 9',
#     'slug': 'liber-studiorum-print',
#     'object': 'Print',
#     'museum_number': 'CAI.525',
#     'place': 'Britain',
#     'primary_image_id': '2017JR8529',
#     'date_text': 'ca. early 19th century'},
#    'pk': 16410,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': 'cai533',
#     'artist': 'Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Liber Studiorum',
#     'collection_code': 'PDP',
#     'object_number': 'O517157',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level C, case IONIDES, shelf 9',
#     'slug': 'liber-studiorum-print',
#     'object': 'Print',
#     'museum_number': 'CAI.533',
#     'place': 'Britain',
#     'primary_image_id': '2017JR8530',
#     'date_text': 'ca. early 19th century'},
#    'pk': 5220,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': 'cai538',
#     'artist': 'Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Liber Studiorum',
#     'collection_code': 'PDP',
#     'object_number': 'O517152',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level C, case Ionides , shelf 9',
#     'slug': 'liber-studiorum-print',
#     'object': 'Print',
#     'museum_number': 'CAI.538',
#     'place': 'Britain',
#     'primary_image_id': '2017JR8447',
#     'date_text': 'ca. early 19th century'},
#    'pk': 48607,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': 'cai540',
#     'artist': 'Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Liber Studiorum',
#     'collection_code': 'PDP',
#     'object_number': 'O517150',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level C, case IONIDES, shelf 9',
#     'slug': 'liber-studiorum-print',
#     'object': 'Print',
#     'museum_number': 'CAI.540',
#     'place': 'Britain',
#     'primary_image_id': '2017JR8516',
#     'date_text': 'ca. early 19th century'},
#    'pk': 36394,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': 'cai548',
#     'artist': 'Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Liber Studiorum',
#     'collection_code': 'PDP',
#     'object_number': 'O517142',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level C, case IONIDES, shelf 9',
#     'slug': 'liber-studiorum-print',
#     'object': 'Print',
#     'museum_number': 'CAI.548',
#     'place': 'Britain',
#     'primary_image_id': '2017JR8536',
#     'date_text': 'ca. early 19th century'},
#    'pk': 14950,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': 'cai550',
#     'artist': 'Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Liber Studiorum',
#     'collection_code': 'PDP',
#     'object_number': 'O517140',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level C, case IONIDES, shelf 9',
#     'slug': 'liber-studiorum-print',
#     'object': 'Print',
#     'museum_number': 'CAI.550',
#     'place': 'Britain',
#     'primary_image_id': '2017JR8482',
#     'date_text': 'ca. early 19th century'},
#    'pk': 42488,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': 'cai551',
#     'artist': 'Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Liber Studiorum',
#     'collection_code': 'PDP',
#     'object_number': 'O517139',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level C, case IONIDES, shelf 9',
#     'slug': 'liber-studiorum-print',
#     'object': 'Print',
#     'museum_number': 'CAI.551',
#     'place': 'Britain',
#     'primary_image_id': '2017JR8483',
#     'date_text': 'ca. early 19th century'},
#    'pk': 47718,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': 'cai494',
#     'artist': 'Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Liber Studiorum',
#     'collection_code': 'PDP',
#     'object_number': 'O517196',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level C, case IONIDES, shelf 9',
#     'slug': 'liber-studiorum-print',
#     'object': 'Print',
#     'museum_number': 'CAI.494',
#     'place': 'Britain',
#     'primary_image_id': '2017JR8521',
#     'date_text': 'ca. early 19th century'},
#    'pk': 15160,
#    'model': 'collection.museumobject'},
#   {'fields': {'rights': 3,
#     'museum_number_token': 'cai506',
#     'artist': 'Turner',
#     'sys_updated': '',
#     'latitude': '',
#     'title': 'Liber Studiorum',
#     'collection_code': 'PDP',
#     'object_number': 'O517184',
#     'longitude': '',
#     'location': 'Prints & Drawings Study Room, level C, case Ionides, shelf 25',
#     'slug': 'liber-studiorum-print',
#     'object': 'Print',
#     'museum_number': 'CAI.506',
#     'place': 'Britain',
#     'primary_image_id': '2017JR8525',
#     'date_text': 'ca. early 19th century'},
#    'pk': 40941,
#    'model': 'collection.museumobject'}]}

# %% [markdown]
# So, let’s load it with the load S method from the json module.
#
# ---
#
# If you’re working in the same notebook as before, you should have it imported already. Otherwise you’ll have to import it before you execute this cell.

# %%
artists = ['Turner','Bowie','Westwood','McQueen']

# %%
url = "https://www.vam.ac.uk/api/json/museumobject/search"
for artist in artists:
    resp = requests.get(url,{'q':'Turner'})
    print(resp.status_code)
    collection = json.loads(resp.text)
# Out:
# 200
# 200
# 200
# 200

# %% [markdown]
# Now, you can imagine that if you had a list of artists
#
# ---
#
# you could use a for loop and the get method
#
# ---
#
# to search the collection of the Victoria and Albert Museum for each of them in turn and load them into a dictionary object.
#
# Then use them in whatever data analysis script we like after that.
#
# But, what if the data we’re after is in the html response from a website?

# %%
from lxml import html
url = "https://en.wikipedia.org/wiki/Wiki"
resp = requests.get(url)
tree = ET.ElementTree(element = html.fromstring(resp.text))
root = tree.getroot()
print(root)
# Out:
# <Element html at 0x11085bcb0>

# %% [markdown]
# We can load the response into an Element Tree.
#
# ---
#
# Again, if you’re not working in the same notebook as before, you’ll have to import the Element Tree module.
# So, getting the Wiki web page we can directly load the response into an element tree.
# Sometimes, you might have to sanitise the response a bit when the html is not well formed.
# Fortunately in this case we don’t have to **[at the time of recording this worked, but since then the page has been altered and might not work for you now]**

# %%
for elem in root.iter():
    if elem.tag == 'a':
        link = elem.get("href")
        print(link)
# Out:
# None
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/File:En-Wiki2.ogg
# #mw-head
# #searchInput
# /wiki/Wiki_(disambiguation)
# //upload.wikimedia.org/wikipedia/commons/3/31/Ward_Cunningham%2C_Inventor_of_the_Wiki.webm
# /wiki/File:Ward_Cunningham,_Inventor_of_the_Wiki.webm
# /wiki/Ward_Cunningham
# /wiki/Help:IPA/English
# /wiki/File:En-us-wiki.ogg
# //upload.wikimedia.org/wikipedia/commons/4/46/En-us-wiki.ogg
# /wiki/Help:Pronunciation_respelling_key
# /wiki/Hypertext
# /wiki/Collaborative_editing
# /wiki/Web_browser
# /wiki/Knowledge_base
# /wiki/Wiki_software
# /wiki/Content_management_system
# /wiki/Web_application
# /wiki/Blog_software
# #cite_note-Easy_Wiki_Hosting-1
# /wiki/Markup_language
# /wiki/Online_rich-text_editor
# #cite_note-Britannica-2
# /wiki/Bug_tracking_system
# /wiki/Open-source_software
# /wiki/Proprietary_software
# /wiki/Wikipedia
# #cite_note-Alexa_Top_Sites-3
# /wiki/Knowledge_management
# /wiki/Notetaking_software
# /wiki/Web_community
# /wiki/Intranet
# /wiki/Ward_Cunningham
# /wiki/WikiWikiWeb
# #cite_note-4
# https://en.wiktionary.org/wiki/wiki#Hawaiian
# /wiki/Help:IPA/Hawaiian
# #cite_note-5
# /wiki/Hawaiian_language
# #cite_note-6
# #cite_note-7
# #cite_note-8
# #Characteristics
# #Editing
# #Navigation
# #Consistency
# #Basic_syntax
# #Visual_editing
# #Version_history
# #Edit_summary
# #Navigation_2
# #Linking_and_creating_pages
# #Searching
# #History
# #Alternative_definitions
# #Implementations
# #Trust_and_security
# #Controlling_changes
# #Trustworthiness_and_reliability_of_content
# #Security
# #Potential_malware_vector
# #Communities
# #Applications
# #City_wikis
# #WikiNodes
# #Participants
# #Growth_factors
# #Conferences
# #Rules
# #Legal_environment
# #See_also
# #Notes
# #References
# #Further_reading
# #External_links
# /wiki/File:Question_book-new.svg
# /wiki/Wikipedia:Verifiability
# https://en.wikipedia.org/w/index.php?title=Wiki&action=edit
# /wiki/Help:Referencing_for_beginners
# /wiki/Help:Maintenance_template_removal
# /wiki/File:Ward_Cunningham_-_Commons-1.jpg
# /wiki/File:Ward_Cunningham_-_Commons-1.jpg
# /wiki/Ward_Cunningham
# /wiki/Bo_Leuf
# /wiki/The_Wiki_Way
# #cite_note-9
# /wiki/Web_page
# /wiki/Vanilla_software
# /wiki/Browser_extension
# /wiki/Internet
# /wiki/Web_browser
# /wiki/Simple_markup_language
# /wiki/MediaWiki_markup_language
# /wiki/Hyperlink
# #cite_note-Legal-10
# /wiki/User_(computing)
# /wiki/Real-time_web
# /wiki/Authentication
# /wiki/Maged_N._Kamel_Boulos
# /wiki/Steve_Wheeler
# /wiki/Social_Darwinism
# #cite_note-BMC-11
# /wiki/Help:Wikitext
# /wiki/Help:Wikitext
# /wiki/Help:Cheatsheet
# /wiki/Help:Wikitext
# /wiki/Help:Magic_links
# /wiki/Help:Visual_file_markup
# /wiki/Help:Sound_file_markup
# /wiki/Help:Table
# /wiki/Help:A_quick_guide_to_templates
# /wiki/Help:HTML_in_wikitext
# /wiki/Template:Wikitext_navbox
# /wiki/Template_talk:Wikitext_navbox
# https://en.wikipedia.org/w/index.php?title=Template:Wikitext_navbox&action=edit
# /wiki/WYSIWYG
# #Visual_editing
# /wiki/Asterisk
# /wiki/Bullet_(typography)
# /wiki/Wikipedia:AUDIENCE
# /wiki/HTML_tag
# /wiki/Cascading_Style_Sheets
# /wiki/JavaScript
# /wiki/MediaWiki
# /wiki/Tea
# /wiki/WYSIWYG
# /wiki/HTML_element
# /wiki/Transparency_(human-computer_interaction)
# /wiki/VisualEditor
# /wiki/Help:Edit_summary
# /wiki/MediaWiki
# /wiki/Wikipedia
# /wiki/Revision_control
# /wiki/Hypertext
# /wiki/Ad_hoc
# /wiki/Backlink
# /wiki/Cold_weather_cycling
# /wiki/Wikipedia:Citation_needed
# /wiki/CamelCase
# /wiki/Capital_letter
# /wiki/Search_algorithm
# /wiki/Full_text_search
# /wiki/PmWiki
# /wiki/Flat_file
# #cite_note-Augar-12
# /wiki/Lee_Daniel_Crocker
# /wiki/Wikipedia:Citation_needed
# /wiki/Web_search_engine
# /wiki/Google_Search
# /wiki/History_of_wikis
# /wiki/File:HNL_Wiki_Wiki_Bus.jpg
# /wiki/File:HNL_Wiki_Wiki_Bus.jpg
# /wiki/Wiki_Wiki_Shuttle
# /wiki/Honolulu_International_Airport
# /wiki/WikiWikiWeb
# #cite_note-ebersbach10-13
# /wiki/Domain_name
# /wiki/C2.com
# /wiki/Honolulu_International_Airport
# /wiki/Wiki_Wiki_Shuttle
# #cite_note-cunningham-14
# #cite_note-history-15
# /wiki/Apple_Inc.
# /wiki/HyperCard
# #cite_note-artima-16
# /wiki/Vannevar_Bush
# #cite_note-Britannica-2
# #cite_note-hypercard-17
# /wiki/Pattern_language
# #cite_note-artima-16
# /wiki/Wikipedia
# /wiki/Corporate_wiki
# /wiki/Group_learning
# /wiki/Firewall_(computing)
# /wiki/Oxford_English_Dictionary
# #cite_note-OED1-18
# #cite_note-Easy_Wiki_Hosting-1
# #cite_note-19
# /wiki/Distributed_version_control
# #cite_note-20
# /wiki/List_of_wiki_software
# /wiki/Wiki_software
# /wiki/Collaborative_software
# /wiki/Web_server
# /wiki/Application_server
# /wiki/File_system
# /wiki/Relational_database_management_system
# /wiki/MediaWiki
# /wiki/Wikipedia
# /wiki/Personal_wiki
# /wiki/Wiki_farm
# /wiki/Comparison_of_wiki_farms
# /wiki/Help:Recent_changes
# /wiki/Special:RecentChanges
# /wiki/File:History_Comparison_Example_(Vector).png
# /wiki/File:History_Comparison_Example_(Vector).png
# #cite_note-21
# /wiki/Internet_bot
# #cite_note-22
# /wiki/Changelog
# /wiki/Diff
# #cite_note-23
# #cite_note-24
# #cite_note-25
# #cite_note-Britannica-2
# /wiki/Lars_Aronsson
# /wiki/Graffiti
# #cite_note-ebersbach10-13
# #cite_note-26
# #cite_note-27
# #cite_note-Noveck-28
# /wiki/Edit_conflict
# /wiki/Wikipedia:Edit_warring
# /wiki/Cybervandalism
# /wiki/Hoax
# /wiki/Wikimedia_Foundation
# /wiki/Vandalism
# /wiki/Troll_(Internet)
# /wiki/Soft_security
# #cite_note-29
# /wiki/Wikipedia:Reliable_sources
# /wiki/Machine_learning
# /wiki/Heuristic_(computer_science)
# #cite_note-30
# /wiki/IP_address
# #cite_note-31
# #cite_note-Legal-10
# #cite_note-Augar-12
# /wiki/Malware
# /wiki/Blaster_Worm
# #cite_note-Legal-10
# /wiki/Blacklist
# #cite_note-32
# /wiki/File:EnglishWikipedia_29June2017.png
# /wiki/File:EnglishWikipedia_29June2017.png
# /wiki/World_Wide_Web
# #cite_note-33
# #cite_note-34
# /wiki/WikiWikiWeb
# /wiki/Memory_Alpha
# /wiki/Wikivoyage
# /wiki/Susning.nu
# /wiki/List_of_medical_wikis
# /wiki/Ganfyd
# #cite_note-BMC-11
# /wiki/Online_community
# /wiki/Enterprise_software
# /wiki/Internal_documentation
# #cite_note-35
# #cite_note-36
# #cite_note-37
# #cite_note-38
# /wiki/Wikipedia:Manual_of_Style/Dates_and_numbers#Chronological_items
# /wiki/Project_management
# #cite_note-39
# #cite_note-40
# /wiki/Wikipedia:Reliable_sources
# #cite_note-41
# /wiki/Grant_writing
# /wiki/Strategic_planning
# #cite_note-42
# #cite_note-Legal-10
# /wiki/Central_Intelligence_Agency
# /wiki/Intellipedia
# /wiki/Intelligence_assessment
# /wiki/American_Civil_Liberties_Union
# /wiki/Guant%C3%A1namo_Bay
# #cite_note-43
# /wiki/United_States_Court_of_Appeals_for_the_Seventh_Circuit
# /wiki/United_States_Patent_and_Trademark_Office
# /wiki/Peer-to-Patent
# /wiki/Prior_art
# /wiki/Queens
# /wiki/Cornell_Law_School
# #cite_note-Noveck-28
# #cite_note-44
# #cite_note-45
# /wiki/Knowledge_management
# /wiki/Social_network
# /wiki/Geography
# #cite_note-46
# #cite_note-47
# #cite_note-48
# /wiki/Encyclopedia
# /wiki/Wikipedia
# /wiki/Wikipedia:WikiNode
# /wiki/WikiNodes
# //upload.wikimedia.org/wikipedia/commons/6/6a/Development_of_%22Mathe_f%C3%BCr_Nicht-Freaks%22_from_Sep_2009_to_June_2016.webm
# /wiki/File:Development_of_%22Mathe_f%C3%BCr_Nicht-Freaks%22_from_Sep_2009_to_June_2016.webm
# https://en.wikibooks.org/wiki/de:Mathe_f%C3%BCr_Nicht-Freaks
# #cite_note-49
# /wiki/Wikipedia:TourBusStop
# #cite_note-50
# #cite_note-51
# #cite_note-52
# /wiki/Atlassian
# /wiki/Confluence_(software)
# #cite_note-53
# /wiki/OpenSym
# /wiki/Academic_conference
# /wiki/Semantic_MediaWiki
# #cite_note-54
# /wiki/Tiki_Wiki_CMS_Groupware
# #cite_note-55
# /wiki/Wikimania
# /wiki/Wikimedia_Foundation
# /wiki/RecentChangesCamp
# /wiki/Unconference
# #cite_note-56
# /wiki/Conservapedia
# /wiki/Before_Christ
# /wiki/B.C.E.
# /wiki/Common_Era
# #cite_note-57
# /wiki/The_Golden_Rule
# #cite_note-Augar-12
# /wiki/Tenants_in_common
# #cite_note-Legal-10
# /wiki/Collective_work
# #cite_note-58
# /wiki/Open_content
# /wiki/GNU_Free_Documentation_License
# /wiki/Creative_Commons
# /wiki/Wikipedia:Citation_needed
# #cite_note-Legal-10
# /wiki/Section_230_of_the_Communications_Decency_Act
# /wiki/Good_Samaritan
# #cite_note-59
# #cite_note-60
# /wiki/Defamation
# /wiki/Internet_service_provider
# #cite_note-Legal-10
# #cite_note-61
# /wiki/File:Crystal_Clear_app_linneighborhood.svg
# /wiki/Portal:Internet
# /wiki/Comparison_of_wiki_software
# /wiki/Content_management_system
# /wiki/CURIE
# /wiki/Dispersed_knowledge
# /wiki/List_of_wikis
# /wiki/Mass_collaboration
# /wiki/Universal_Edit_Button
# /wiki/Wikis_and_education
# #cite_ref-5
# /wiki/Phoneme
# /wiki/Hawaiian_phonology
# #cite_ref-Easy_Wiki_Hosting_1-0
# #cite_ref-Easy_Wiki_Hosting_1-1
# http://msdn.microsoft.com/en-us/magazine/cc700339.aspx
# https://web.archive.org/web/20100316192702/http://msdn.microsoft.com/en-us/magazine/cc700339.aspx
# #cite_ref-Britannica_2-0
# #cite_ref-Britannica_2-1
# #cite_ref-Britannica_2-2
# http://www.britannica.com/EBchecked/topic/1192819/wiki
# /wiki/Encyclop%C3%A6dia_Britannica
# /wiki/Encyclop%C3%A6dia_Britannica,_Inc.
# https://web.archive.org/web/20080424074513/http://www.britannica.com/EBchecked/topic/1192819/wiki
# #cite_ref-Alexa_Top_Sites_3-0
# http://www.alexa.com/topsites
# https://web.archive.org/web/20150302173920/http://www.alexa.com/topsites
# #cite_ref-4
# /wiki/Ward_Cunningham
# http://www.wiki.org/wiki.cgi?WhatIsWiki
# https://web.archive.org/web/20080416212802/http://www.wiki.org/wiki.cgi?WhatIsWiki
# #cite_ref-6
# http://www.mauimapp.com/moolelo/hwnwdshw.htm
# https://web.archive.org/web/20080914154748/http://www.mauimapp.com/moolelo/hwnwdshw.htm
# #cite_ref-7
# https://archive.org/details/wikipedia35milli0000hasa/page/11
# https://archive.org/details/wikipedia35milli0000hasa/page/11
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9781448855575
# https://web.archive.org/web/20191026122531/https://archive.org/details/wikipedia35milli0000hasa/page/11
# #cite_ref-8
# https://archive.org/details/dictionaryofhawa00andrrich/
# https://web.archive.org/web/20140815064248/https://archive.org/details/dictionaryofhawa00andrrich/
# #cite_ref-9
# #CITEREFLeufCunningham2001
# http://c2.com/cgi/wiki?WikiDesignPrinciples
# https://web.archive.org/web/20020430181259/http://c2.com/cgi/wiki?WikiDesignPrinciples
# /wiki/Category:CS1_maint:_archived_copy_as_title
# #cite_ref-Legal_10-0
# #cite_ref-Legal_10-1
# #cite_ref-Legal_10-2
# #cite_ref-Legal_10-3
# #cite_ref-Legal_10-4
# #cite_ref-Legal_10-5
# #cite_ref-Legal_10-6
# https://web.archive.org/web/20121222125337/https://elaw.murdoch.edu.au/archives/issues/2007/1/eLaw_legal%20issues%20for%20wikis.pdf
# https://elaw.murdoch.edu.au/archives/issues/2007/1/eLaw_legal%20issues%20for%20wikis.pdf
# #cite_ref-BMC_11-0
# #cite_ref-BMC_11-1
# /wiki/Doi_(identifier)
# https://doi.org/10.1186%2F1472-6920-6-41
# /wiki/PMC_(identifier)
# //www.ncbi.nlm.nih.gov/pmc/articles/PMC1564136
# /wiki/PMID_(identifier)
# //pubmed.ncbi.nlm.nih.gov/16911779
# #cite_ref-Augar_12-0
# #cite_ref-Augar_12-1
# #cite_ref-Augar_12-2
# /wiki/CiteSeerX_(identifier)
# //citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.133.1456
# /wiki/Help:CS1_errors#missing_periodical
# #cite_ref-ebersbach10_13-0
# #cite_ref-ebersbach10_13-1
# #CITEREFEbersbach2008
# #cite_ref-cunningham_14-0
# http://c2.com/doc/etymology.html
# https://web.archive.org/web/20070317120823/http://c2.com/doc/etymology.html
# #cite_ref-history_15-0
# http://c2.com/cgi/wiki?WikiHistory
# https://web.archive.org/web/20020621221535/http://c2.com/cgi/wiki?WikiHistory
# #cite_ref-artima_16-0
# #cite_ref-artima_16-1
# http://www.artima.com/intv/wiki.html
# https://web.archive.org/web/20150205091836/http://www.artima.com/intv/wiki.html
# #cite_ref-hypercard_17-0
# http://c2.com/cgi/wiki?WikiWikiHyperCard
# https://web.archive.org/web/20070406064446/http://c2.com/cgi/wiki?WikiWikiHyperCard
# #cite_ref-OED1_18-0
# http://www.oed.com/public/update0703/march-2007-update
# /wiki/Oxford_English_Dictionary
# https://web.archive.org/web/20110107132110/http://www.oed.com/public/update0703/march-2007-update
# #cite_ref-19
# /wiki/Ward_Cunningham
# https://twitter.com/WardCunningham/status/531149812976996352
# /wiki/Twitter
# #cite_ref-20
# http://forage.ward.fed.wiki.org/view/an-install-of-wiki
# https://web.archive.org/web/20150928165957/http://forage.ward.fed.wiki.org/view/an-install-of-wiki
# #cite_ref-21
# #CITEREFEbersbach2008
# #cite_ref-22
# #CITEREFEbersbach2008
# #cite_ref-23
# #CITEREFEbersbach2008
# #cite_ref-24
# #CITEREFEbersbach2008
# #cite_ref-25
# #cite_ref-26
# http://circle.ubc.ca/bitstream/handle/2429/497/c07-036.pdf
# /wiki/Doi_(identifier)
# https://doi.org/10.5596%2Fc07-036
# /wiki/ISSN_(identifier)
# //www.worldcat.org/issn/1708-6892
# https://web.archive.org/web/20120430195019/https://circle.ubc.ca/bitstream/handle/2429/497/c07-036.pdf
# #cite_ref-27
# https://doi.org/10.1038%2F440278a
# /wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2006Natur.440..278Y
# /wiki/Doi_(identifier)
# https://doi.org/10.1038%2F440278a
# /wiki/PMID_(identifier)
# //pubmed.ncbi.nlm.nih.gov/16541049
# #cite_ref-Noveck_28-0
# #cite_ref-Noveck_28-1
# http://heinonline.org/HOL/LandingPage?collection=journals&handle=hein.journals/jled57&div=8&id=&page=
# https://web.archive.org/web/20140703005842/http://heinonline.org/HOL/LandingPage?collection=journals&handle=hein.journals%2Fjled57&div=8&id=&page=
# #cite_ref-29
# https://web.archive.org/web/20140106040941/http://m3m.homelinux.org/wikiMC/index.php/Security
# http://m3m.homelinux.org/wikiMC/index.php/Security
# #cite_ref-30
# https://www.theverge.com/2014/2/18/5412636/this-machine-kills-trolls-how-wikipedia-robots-snuff-out-vandalism
# https://web.archive.org/web/20140827115824/http://www.theverge.com/2014/2/18/5412636/this-machine-kills-trolls-how-wikipedia-robots-snuff-out-vandalism
# #cite_ref-31
# #CITEREFEbersbach2008
# #cite_ref-32
# https://meta.wikimedia.org/wiki/Spam_blacklist/About
# #cite_ref-33
# https://web.archive.org/web/20140825164715/http://s23.org/wikistats/largest_html.php?sort=users_desc&th=8000&lines=500
# http://s23.org/wikistats/largest_html.php?sort=users_desc&th=8000&lines=500
# #cite_ref-34
# http://www.alexa.com/topsites
# /wiki/Alexa_Internet
# https://web.archive.org/web/20150302173920/http://www.alexa.com/topsites
# #cite_ref-35
# https://web.archive.org/web/20110706095145/http://i-know.tugraz.at/wp-content/uploads/2008/11/47_wikis-for-collaborative-software-documentation.pdf
# http://i-know.tugraz.at/wp-content/uploads/2008/11/47_wikis-for-collaborative-software-documentation.pdf
# /wiki/Help:CS1_errors#missing_periodical
# #cite_ref-36
# /wiki/Doi_(identifier)
# https://doi.org/10.1145%2F1149453.1149472
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-1-59593-413-0
# #cite_ref-37
# http://research.microsoft.com/apps/pubs/default.aspx?id=138573
# https://web.archive.org/web/20150904031729/http://research.microsoft.com/apps/pubs/default.aspx?id=138573
# #cite_ref-38
# http://www.businessweek.com/stories/2005-11-27/e-mail-is-so-five-minutes-ago
# https://web.archive.org/web/20121017131307/http://www.businessweek.com/stories/2005-11-27/e-mail-is-so-five-minutes-ago
# #cite_ref-39
# http://projectmanagementwiki.org
# https://web.archive.org/web/20140816221509/http://projectmanagementwiki.org/
# #cite_ref-40
# http://www.editme.com/Ways-to-Wiki-Project-Management
# https://web.archive.org/web/20120508152328/http://www.editme.com/Ways-to-Wiki-Project-Management
# #cite_ref-41
# http://portal.acm.org/citation.cfm?id=1142215.1142259
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-2-84426-314-8
# #cite_ref-42
# /wiki/Doi_(identifier)
# https://doi.org/10.1080%2F02763860802114223
# /wiki/PMID_(identifier)
# //pubmed.ncbi.nlm.nih.gov/18844087
# #cite_ref-43
# https://www.dailykos.com/story/2005/06/09/120607/-SusanHu-s-FOIA-Project-UPDATE
# https://web.archive.org/web/20130530181455/http://www.dailykos.com/story/2005/06/09/120607/-SusanHu-s-FOIA-Project-UPDATE
# #cite_ref-44
# /wiki/Doi_(identifier)
# https://doi.org/10.1109%2FIEEM.2017.8290296
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-1-5386-0948-4
# #cite_ref-45
# http://www.iaeng.org/publication/WCECS2014/WCECS2014_pp358-363.pdf
# https://web.archive.org/web/20190412152358/http://www.iaeng.org/publication/WCECS2014/WCECS2014_pp358-363.pdf
# #cite_ref-46
# http://www.niemanlab.org/2009/11/welcome-to-davis-calif-six-lessons-from-the-worlds-best-local-wiki/
# https://web.archive.org/web/20130808084426/http://www.niemanlab.org/2009/11/welcome-to-davis-calif-six-lessons-from-the-worlds-best-local-wiki/
# /wiki/Wayback_Machine
# #cite_ref-47
# http://www.niemanlab.org/2010/06/knight-news-challenge-is-a-wiki-site-coming-to-your-city-local-wiki-will-build-software-to-make-it-simple/
# https://web.archive.org/web/20130625035936/http://www.niemanlab.org/2010/06/knight-news-challenge-is-a-wiki-site-coming-to-your-city-local-wiki-will-build-software-to-make-it-simple/
# /wiki/Wayback_Machine
# #cite_ref-48
# /wiki/Wired_(magazine)
# http://archive.wired.com/geekdad/2009/07/hey-kid-support-your-local-wiki/
# https://web.archive.org/web/20150427080359/http://archive.wired.com/geekdad/2009/07/hey-kid-support-your-local-wiki/
# /wiki/Wayback_Machine
# #cite_ref-49
# https://web.archive.org/web/20070810213702/http://wikinodes.wiki.taoriver.net/moin.fcg/FrequentlyAskedQuestions
# http://wikinodes.wiki.taoriver.net/moin.fcg/FrequentlyAskedQuestions
# #cite_ref-50
# https://web.archive.org/web/20110515005430/https://uhra.herts.ac.uk/dspace/handle/2299/3672
# https://uhra.herts.ac.uk/dspace/handle/2299/3672
# /wiki/Help:CS1_errors#missing_periodical
# #cite_ref-51
# http://nitens.org/docs/wikidyn.pdf
# https://web.archive.org/web/20171011105517/http://nitens.org/docs/wikidyn.pdf
# /wiki/Help:CS1_errors#missing_periodical
# #cite_ref-52
# https://web.archive.org/web/20120616204038/http://epubs.surrey.ac.uk/1565/1/fulltext.pdf#
# http://epubs.surrey.ac.uk:80/1565/1/fulltext.pdf
# /wiki/Help:CS1_errors#missing_periodical
# #cite_ref-53
# http://summit.atlassian.com/
# https://web.archive.org/web/20110613081406/http://summit.atlassian.com/
# #cite_ref-54
# http://semantic-mediawiki.org/wiki/SMWCon
# https://web.archive.org/web/20110714183910/http://semantic-mediawiki.org/wiki/SMWCon
# #cite_ref-55
# http://tiki.org/TikiFest
# https://web.archive.org/web/20110630070137/http://tiki.org/TikiFest
# #cite_ref-56
# http://wiki.regiowiki.eu/Main_Page
# https://web.archive.org/web/20090813101324/http://wiki.regiowiki.eu/Main_Page
# #cite_ref-57
# http://www.conservapedia.com/Conservapedia:Commandments
# https://web.archive.org/web/20101022014810/http://conservapedia.com/Conservapedia:Commandments
# #cite_ref-58
# /wiki/Help:CS1_errors#citation_missing_title
# #cite_ref-59
# http://works.bepress.com/cgi/viewcontent.cgi?article=1000&context=sarah_oh
# https://web.archive.org/web/20140106040705/http://works.bepress.com/cgi/viewcontent.cgi?article=1000&context=sarah_oh
# /wiki/Help:CS1_errors#missing_periodical
# #cite_ref-60
# /wiki/SSRN_(identifier)
# //ssrn.com/abstract=916529
# #cite_ref-61
# http://heinonline.org/HOL/LandingPage?collection=journals&handle=hein.journals/manintpr179&div=31&id=&page=
# https://web.archive.org/web/20160304044437/http://heinonline.org/HOL/LandingPage?collection=journals&handle=hein.journals%2Fmanintpr179&div=31&id=&page=
# /wiki/Springer_Science%2BBusiness_Media
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-3-540-35150-4
# https://archive.org/details/isbn_9780201714999
# /wiki/Addison%E2%80%93Wesley
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-201-71499-9
# https://archive.org/details/wikipatternsapra00made
# /wiki/John_Wiley_%26_Sons
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-470-22362-8
# /wiki/Mass_Collaboration
# /wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-1-59184-193-7
# /wiki/File:En-Wiki2.ogg
# /wiki/Wikipedia:Media_help
# /wiki/Wikipedia:Spoken_articles
# /wiki/Wikipedia:Wikimedia_sister_projects
# https://en.wiktionary.org/wiki/wiki
# https://commons.wikimedia.org/wiki/category:Wiki_software
# https://en.wikinews.org/wiki/Special:Search/Wiki
# https://en.wikiversity.org/wiki/Special:Search/Wiki
# https://www.wikidata.org/wiki/Q171
# https://www.mediawiki.org/wiki/wiki
# https://curlie.org/Computers/Software/Groupware/Wiki/
# /wiki/Curlie
# http://www.artima.com/intv/wiki.html
# /wiki/Ward_Cunningham
# http://wikiindex.org/Welcome
# https://wikiapiary.com
# http://www.wikimatrix.org/
# https://github.com/WikiTeam/wikiteam
# /wiki/Archive_Team
# https://web.archive.org/web/20110709101821/http://www.ucop.edu/tltc/news/2006/04/wiki.html
# /wiki/University_of_California
# http://c2.com/doc/etymology.html
# /wiki/Template:Wikis
# /wiki/Template_talk:Wikis
# https://en.wikipedia.org/w/index.php?title=Template:Wikis&action=edit
# None
# /wiki/Personal_wiki
# /wiki/List_of_medical_wikis
# /wiki/Semantic_wiki
# /wiki/Wiki_hosting_service
# /wiki/Wiki_software
# /wiki/Interwiki_links
# /wiki/List_of_wikis
# /wiki/List_of_wiki_software
# /wiki/Comparison_of_wiki_software
# /wiki/Comparison_of_wiki_hosting_services
# /wiki/History_of_wikis
# /wiki/Creole_(markup)
# /wiki/Template:Wiki_software
# /wiki/Template_talk:Wiki_software
# https://en.wikipedia.org/w/index.php?title=Template:Wiki_software&action=edit
# /wiki/Wiki_software
# /wiki/.NET_Framework
# /wiki/FlexWiki
# /wiki/Microsoft_SharePoint
# /wiki/Java_(programming_language)
# /wiki/Confluence_(software)
# /wiki/Jive_(software)
# /wiki/Traction_TeamPage
# /wiki/XWiki
# /wiki/JavaScript
# /wiki/Nuclino
# /wiki/TiddlyWiki
# /wiki/Wiki.js
# /wiki/Perl
# /wiki/Foswiki
# /wiki/Ikiwiki
# /wiki/TWiki
# /wiki/UseModWiki
# /wiki/WikiWikiWeb
# /wiki/PHP
# /wiki/DokuWiki
# /wiki/MediaWiki
# /wiki/MindTouch
# /wiki/PhpWiki
# /wiki/Phabricator
# /wiki/PmWiki
# /wiki/Tiki_Wiki_CMS_Groupware
# /wiki/PukiWiki
# /wiki/Python_(programming_language)
# /wiki/Apache_Allura
# /wiki/Apache_Bloodhound
# /wiki/Kallithea_(software)
# /wiki/Kuma_(software)
# /wiki/MoinMoin
# /wiki/Trac
# /wiki/Zwiki
# /wiki/Ruby_(programming_language)
# /wiki/Redmine
# /wiki/Wagn_(software)
# /wiki/Gollum_Wiki
# /wiki/CLiki
# /wiki/Common_Lisp
# /wiki/Gitit_(software)
# /wiki/Haskell_(programming_language)
# /wiki/Category:Wiki_software
# /wiki/Comparison_of_wiki_software
# /wiki/List_of_wiki_software
# /wiki/Template:Computer-mediated_communication
# /wiki/Template_talk:Computer-mediated_communication
# https://en.wikipedia.org/w/index.php?title=Template:Computer-mediated_communication&action=edit
# /wiki/Computer-mediated_communication
# /wiki/Online_chat
# /wiki/Online_discussion
# /wiki/Communication_software
# /wiki/Collaborative_software
# /wiki/Social_network_service
# /wiki/Virtual_learning_environment
# /wiki/Asynchronous_conferencing
# /wiki/Email
# /wiki/Electronic_mailing_list
# /wiki/FidoNet
# /wiki/Usenet
# /wiki/Internet_forum
# /wiki/Textboard
# /wiki/Imageboard
# /wiki/Shoutbox
# /wiki/Bulletin_board_system
# /wiki/Guestbook
# /wiki/Synchronous_conferencing
# /wiki/Data_conferencing
# /wiki/Instant_messaging
# /wiki/Internet_Relay_Chat
# /wiki/LAN_messenger
# /wiki/Talker
# /wiki/Videoconferencing
# /wiki/Voice_over_IP
# /wiki/Voice_chat_in_online_gaming
# /wiki/Web_chat
# /wiki/Web_conferencing
# /wiki/Blog
# /wiki/Microblogging
# None
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q171#identifiers
# /wiki/GND_(identifier)
# https://d-nb.info/gnd/4806885-8
# /wiki/LCCN_(identifier)
# https://id.loc.gov/authorities/subjects/sh00004800
# https://en.wikipedia.org/w/index.php?title=Wiki&oldid=991544914
# /wiki/Help:Category
# /wiki/Category:Wikis
# /wiki/Category:Hawaiian_words_and_phrases
# /wiki/Category:Hypertext
# /wiki/Category:Self-organization
# /wiki/Category:Social_information_processing
# /wiki/Category:CS1_maint:_archived_copy_as_title
# /wiki/Category:CS1_errors:_missing_periodical
# /wiki/Category:Pages_containing_links_to_subscription-only_content
# /wiki/Category:Webarchive_template_wayback_links
# /wiki/Category:Pages_with_citations_lacking_titles
# /wiki/Category:CS1:_long_volume_value
# /wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# /wiki/Category:Wikipedia_indefinitely_move-protected_pages
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Use_mdy_dates_from_July_2019
# /wiki/Category:Articles_with_hAudio_microformats
# /wiki/Category:Pages_including_recorded_pronunciations
# /wiki/Category:Articles_needing_additional_references_from_March_2017
# /wiki/Category:All_articles_needing_additional_references
# /wiki/Category:All_articles_needing_examples
# /wiki/Category:Articles_needing_examples_from_August_2018
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_July_2013
# /wiki/Category:Articles_with_unsourced_statements_from_April_2020
# /wiki/Category:All_articles_lacking_reliable_references
# /wiki/Category:Articles_lacking_reliable_references_from_July_2013
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_July_2013
# /wiki/Category:All_Wikipedia_articles_in_need_of_updating
# /wiki/Category:Spoken_articles
# /wiki/Category:Articles_with_Curlie_links
# /wiki/Category:Wikipedia_articles_with_GND_identifiers
# /wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# /wiki/Category:Articles_containing_video_clips
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Wiki
# /w/index.php?title=Special:UserLogin&returnto=Wiki
# /wiki/Wiki
# /wiki/Talk:Wiki
# /wiki/Wiki
# /w/index.php?title=Wiki&action=edit
# /w/index.php?title=Wiki&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:WhatLinksHere/Wiki
# /wiki/Special:RecentChangesLinked/Wiki
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Wiki&oldid=991544914
# /w/index.php?title=Wiki&action=info
# /w/index.php?title=Special:CiteThisPage&page=Wiki&id=991544914&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q171
# /w/index.php?title=Special:DownloadAsPdf&page=Wiki&action=show-download-screen
# /w/index.php?title=Wiki&printable=yes
# https://commons.wikimedia.org/wiki/Category:Wiki
# https://meta.wikimedia.org/wiki/Wiki
# https://af.wikipedia.org/wiki/Wiki
# https://als.wikipedia.org/wiki/Wiki
# https://ar.wikipedia.org/wiki/%D9%88%D9%8A%D9%83%D9%8A
# https://an.wikipedia.org/wiki/Wiki
# https://as.wikipedia.org/wiki/%E0%A7%B1%E0%A6%BF%E0%A6%95%E0%A6%BF
# https://ast.wikipedia.org/wiki/Wiki
# https://az.wikipedia.org/wiki/Viki
# https://bm.wikipedia.org/wiki/Wiki
# https://bn.wikipedia.org/wiki/%E0%A6%89%E0%A6%87%E0%A6%95%E0%A6%BF
# https://bjn.wikipedia.org/wiki/Wiki
# https://zh-min-nan.wikipedia.org/wiki/Wiki
# https://ba.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://be.wikipedia.org/wiki/%D0%92%D1%96%D0%BA%D1%96
# https://be-tarask.wikipedia.org/wiki/%D0%92%D1%96%D0%BA%D1%96
# https://bg.wikipedia.org/wiki/%D0%A3%D0%B8%D0%BA%D0%B8
# https://bar.wikipedia.org/wiki/Wiki
# https://bs.wikipedia.org/wiki/Wiki
# https://br.wikipedia.org/wiki/Wiki
# https://bxr.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://ca.wikipedia.org/wiki/Wiki
# https://cv.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://ceb.wikipedia.org/wiki/Wiki
# https://cs.wikipedia.org/wiki/Wiki
# https://co.wikipedia.org/wiki/Wiki
# https://cy.wikipedia.org/wiki/Wici
# https://da.wikipedia.org/wiki/Wiki
# https://de.wikipedia.org/wiki/Wiki
# https://et.wikipedia.org/wiki/Viki
# https://el.wikipedia.org/wiki/Wiki
# https://es.wikipedia.org/wiki/Wiki
# https://eo.wikipedia.org/wiki/Vikio
# https://eu.wikipedia.org/wiki/Wiki
# https://fa.wikipedia.org/wiki/%D9%88%DB%8C%DA%A9%DB%8C
# https://fo.wikipedia.org/wiki/Wiki
# https://fr.wikipedia.org/wiki/Wiki
# https://fur.wikipedia.org/wiki/Wiki
# https://ga.wikipedia.org/wiki/Vic%C3%AD
# https://gl.wikipedia.org/wiki/Wiki
# https://inh.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://xal.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://ko.wikipedia.org/wiki/%EC%9C%84%ED%82%A4
# https://hy.wikipedia.org/wiki/%D5%8E%D5%AB%D6%84%D5%AB
# https://hi.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%95%E0%A4%BF
# https://hr.wikipedia.org/wiki/Wiki
# https://ig.wikipedia.org/wiki/Wiki
# https://ilo.wikipedia.org/wiki/Wiki
# https://bpy.wikipedia.org/wiki/%E0%A6%89%E0%A6%87%E0%A6%95%E0%A6%BF
# https://id.wikipedia.org/wiki/Wiki
# https://ia.wikipedia.org/wiki/Wiki
# https://iu.wikipedia.org/wiki/%E1%90%85%E1%90%83%E1%91%AD
# https://is.wikipedia.org/wiki/Wiki
# https://it.wikipedia.org/wiki/Wiki
# https://he.wikipedia.org/wiki/%D7%95%D7%99%D7%A7%D7%99
# https://jv.wikipedia.org/wiki/Wiki
# https://kn.wikipedia.org/wiki/%E0%B2%B5%E0%B2%BF%E0%B2%95%E0%B2%BF
# https://ka.wikipedia.org/wiki/Wiki
# https://kk.wikipedia.org/wiki/%D0%A3%D0%B8%D0%BA%D0%B8
# https://sw.wikipedia.org/wiki/Wiki
# https://gcr.wikipedia.org/wiki/Wiki
# https://ky.wikipedia.org/wiki/%D0%A3%D0%B8%D0%BA%D0%B8
# https://la.wikipedia.org/wiki/Vici
# https://lv.wikipedia.org/wiki/Vikivietne
# https://lb.wikipedia.org/wiki/Wiki
# https://lt.wikipedia.org/wiki/Wiki
# https://li.wikipedia.org/wiki/Wiki
# https://lfn.wikipedia.org/wiki/Vici
# https://jbo.wikipedia.org/wiki/uitki
# https://lmo.wikipedia.org/wiki/Wiki
# https://hu.wikipedia.org/wiki/Wiki
# https://mk.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://mg.wikipedia.org/wiki/Wiki
# https://ml.wikipedia.org/wiki/%E0%B4%B5%E0%B4%BF%E0%B4%95%E0%B5%8D%E0%B4%95%E0%B4%BF
# https://mt.wikipedia.org/wiki/Wiki
# https://mr.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%95%E0%A5%80
# https://xmf.wikipedia.org/wiki/%E1%83%95%E1%83%98%E1%83%99%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%88%D9%8A%D9%83%D9%89
# https://ms.wikipedia.org/wiki/Wiki
# https://min.wikipedia.org/wiki/Wiki
# https://mn.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://my.wikipedia.org/wiki/%E1%80%9D%E1%80%AE%E1%80%80%E1%80%AE
# https://nah.wikipedia.org/wiki/Huiqui
# https://fj.wikipedia.org/wiki/Wiki
# https://nl.wikipedia.org/wiki/Wiki
# https://nds-nl.wikipedia.org/wiki/Wiki
# https://ne.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%95%E0%A4%BF
# https://ja.wikipedia.org/wiki/%E3%82%A6%E3%82%A3%E3%82%AD
# https://no.wikipedia.org/wiki/Wiki
# https://nn.wikipedia.org/wiki/Wiki
# https://nrm.wikipedia.org/wiki/Ouitchi
# https://oc.wikipedia.org/wiki/Wiki
# https://pa.wikipedia.org/wiki/%E0%A8%B5%E0%A8%BF%E0%A8%95%E0%A9%80
# https://pag.wikipedia.org/wiki/Wiki
# https://nds.wikipedia.org/wiki/Wiki
# https://pl.wikipedia.org/wiki/Wiki
# https://pnt.wikipedia.org/wiki/%CE%92%CE%B9%CE%BA%CE%B9
# https://pt.wikipedia.org/wiki/Wiki
# https://ro.wikipedia.org/wiki/Wiki
# https://qu.wikipedia.org/wiki/Wiki
# https://rue.wikipedia.org/wiki/%D0%92%D1%96%D0%BA%D1%96
# https://ru.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://sa.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%95%E0%A4%BF%E0%A4%83
# https://sc.wikipedia.org/wiki/Wiki
# https://sco.wikipedia.org/wiki/Wiki
# https://sq.wikipedia.org/wiki/Wiki
# https://scn.wikipedia.org/wiki/Wiki
# https://si.wikipedia.org/wiki/%E0%B7%80%E0%B7%92%E0%B6%9A%E0%B7%92
# https://simple.wikipedia.org/wiki/Wiki
# https://sk.wikipedia.org/wiki/Wiki
# https://sl.wikipedia.org/wiki/Wiki
# https://so.wikipedia.org/wiki/Wiki
# https://ckb.wikipedia.org/wiki/%D9%88%DB%8C%DA%A9%DB%8C
# https://sr.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://sh.wikipedia.org/wiki/Wiki
# https://su.wikipedia.org/wiki/Wiki
# https://fi.wikipedia.org/wiki/Wiki
# https://sv.wikipedia.org/wiki/Wiki
# https://tl.wikipedia.org/wiki/Wiki
# https://ta.wikipedia.org/wiki/%E0%AE%B5%E0%AE%BF%E0%AE%95%E0%AF%8D%E0%AE%95%E0%AE%BF
# https://kab.wikipedia.org/wiki/Wiki
# https://tt.wikipedia.org/wiki/Wiki
# https://shn.wikipedia.org/wiki/%E1%80%9D%E1%80%AE%E1%82%87%E1%81%B6%E1%80%AE%E1%82%87
# https://te.wikipedia.org/wiki/%E0%B0%B5%E0%B0%BF%E0%B0%95%E0%B1%80
# https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%81%E0%B8%B4
# https://tg.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://tr.wikipedia.org/wiki/Viki
# https://uk.wikipedia.org/wiki/%D0%92%D1%96%D0%BA%D1%96
# https://ur.wikipedia.org/wiki/%D9%88%DB%8C%DA%A9%DB%8C
# https://vi.wikipedia.org/wiki/Wiki
# https://fiu-vro.wikipedia.org/wiki/Viki
# https://zh-classical.wikipedia.org/wiki/%E5%85%B1%E7%AD%86
# https://war.wikipedia.org/wiki/Wiki
# https://wuu.wikipedia.org/wiki/Wiki
# https://yi.wikipedia.org/wiki/%D7%95%D7%95%D7%99%D7%A7%D7%99
# https://yo.wikipedia.org/wiki/Wiki
# https://zh-yue.wikipedia.org/wiki/Wiki
# https://diq.wikipedia.org/wiki/Wiki
# https://bat-smg.wikipedia.org/wiki/Wiki
# https://zh.wikipedia.org/wiki/Wiki
# https://www.wikidata.org/wiki/Special:EntityPage/Q171#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=Wiki&mobileaction=toggle_view_mobile
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# So, we can traverse and search the elements of the web page.
# Here, for example, we’re just searching for all hyperlink tags and printing the links on the page.
#
# ---
#
# You see that most of them are relative links which are no good as is if we wanted to use them to start crawling the wiki site.
#
# For that we’ll need to use the url join method we imported at the start

# %%
base_url = "https://en.wikipedia.org/"
for elem in root.iter():
    if elem.tag == 'a':
        link = elem.get("href")
        print(link)
        if link is not None and not link.startswith('http'):
            link = urljoin(base_url,link) if not link.startswith('#') else urljoin(url,link)
            print(link)
# Out:
# None
# /wiki/Wikipedia:Protection_policy#semi
# https://en.wikipedia.org/wiki/Wikipedia:Protection_policy#semi
# /wiki/File:En-Wiki2.ogg
# https://en.wikipedia.org/wiki/File:En-Wiki2.ogg
# #mw-head
# https://en.wikipedia.org/wiki/Wiki#mw-head
# #searchInput
# https://en.wikipedia.org/wiki/Wiki#searchInput
# /wiki/Wiki_(disambiguation)
# https://en.wikipedia.org/wiki/Wiki_(disambiguation)
# //upload.wikimedia.org/wikipedia/commons/3/31/Ward_Cunningham%2C_Inventor_of_the_Wiki.webm
# https://upload.wikimedia.org/wikipedia/commons/3/31/Ward_Cunningham%2C_Inventor_of_the_Wiki.webm
# /wiki/File:Ward_Cunningham,_Inventor_of_the_Wiki.webm
# https://en.wikipedia.org/wiki/File:Ward_Cunningham,_Inventor_of_the_Wiki.webm
# /wiki/Ward_Cunningham
# https://en.wikipedia.org/wiki/Ward_Cunningham
# /wiki/Help:IPA/English
# https://en.wikipedia.org/wiki/Help:IPA/English
# /wiki/File:En-us-wiki.ogg
# https://en.wikipedia.org/wiki/File:En-us-wiki.ogg
# //upload.wikimedia.org/wikipedia/commons/4/46/En-us-wiki.ogg
# https://upload.wikimedia.org/wikipedia/commons/4/46/En-us-wiki.ogg
# /wiki/Help:Pronunciation_respelling_key
# https://en.wikipedia.org/wiki/Help:Pronunciation_respelling_key
# /wiki/Hypertext
# https://en.wikipedia.org/wiki/Hypertext
# /wiki/Collaborative_editing
# https://en.wikipedia.org/wiki/Collaborative_editing
# /wiki/Web_browser
# https://en.wikipedia.org/wiki/Web_browser
# /wiki/Knowledge_base
# https://en.wikipedia.org/wiki/Knowledge_base
# /wiki/Wiki_software
# https://en.wikipedia.org/wiki/Wiki_software
# /wiki/Content_management_system
# https://en.wikipedia.org/wiki/Content_management_system
# /wiki/Web_application
# https://en.wikipedia.org/wiki/Web_application
# /wiki/Blog_software
# https://en.wikipedia.org/wiki/Blog_software
# #cite_note-Easy_Wiki_Hosting-1
# https://en.wikipedia.org/wiki/Wiki#cite_note-Easy_Wiki_Hosting-1
# /wiki/Markup_language
# https://en.wikipedia.org/wiki/Markup_language
# /wiki/Online_rich-text_editor
# https://en.wikipedia.org/wiki/Online_rich-text_editor
# #cite_note-Britannica-2
# https://en.wikipedia.org/wiki/Wiki#cite_note-Britannica-2
# /wiki/Bug_tracking_system
# https://en.wikipedia.org/wiki/Bug_tracking_system
# /wiki/Open-source_software
# https://en.wikipedia.org/wiki/Open-source_software
# /wiki/Proprietary_software
# https://en.wikipedia.org/wiki/Proprietary_software
# /wiki/Wikipedia
# https://en.wikipedia.org/wiki/Wikipedia
# #cite_note-Alexa_Top_Sites-3
# https://en.wikipedia.org/wiki/Wiki#cite_note-Alexa_Top_Sites-3
# /wiki/Knowledge_management
# https://en.wikipedia.org/wiki/Knowledge_management
# /wiki/Notetaking_software
# https://en.wikipedia.org/wiki/Notetaking_software
# /wiki/Web_community
# https://en.wikipedia.org/wiki/Web_community
# /wiki/Intranet
# https://en.wikipedia.org/wiki/Intranet
# /wiki/Ward_Cunningham
# https://en.wikipedia.org/wiki/Ward_Cunningham
# /wiki/WikiWikiWeb
# https://en.wikipedia.org/wiki/WikiWikiWeb
# #cite_note-4
# https://en.wikipedia.org/wiki/Wiki#cite_note-4
# https://en.wiktionary.org/wiki/wiki#Hawaiian
# /wiki/Help:IPA/Hawaiian
# https://en.wikipedia.org/wiki/Help:IPA/Hawaiian
# #cite_note-5
# https://en.wikipedia.org/wiki/Wiki#cite_note-5
# /wiki/Hawaiian_language
# https://en.wikipedia.org/wiki/Hawaiian_language
# #cite_note-6
# https://en.wikipedia.org/wiki/Wiki#cite_note-6
# #cite_note-7
# https://en.wikipedia.org/wiki/Wiki#cite_note-7
# #cite_note-8
# https://en.wikipedia.org/wiki/Wiki#cite_note-8
# #Characteristics
# https://en.wikipedia.org/wiki/Wiki#Characteristics
# #Editing
# https://en.wikipedia.org/wiki/Wiki#Editing
# #Navigation
# https://en.wikipedia.org/wiki/Wiki#Navigation
# #Consistency
# https://en.wikipedia.org/wiki/Wiki#Consistency
# #Basic_syntax
# https://en.wikipedia.org/wiki/Wiki#Basic_syntax
# #Visual_editing
# https://en.wikipedia.org/wiki/Wiki#Visual_editing
# #Version_history
# https://en.wikipedia.org/wiki/Wiki#Version_history
# #Edit_summary
# https://en.wikipedia.org/wiki/Wiki#Edit_summary
# #Navigation_2
# https://en.wikipedia.org/wiki/Wiki#Navigation_2
# #Linking_and_creating_pages
# https://en.wikipedia.org/wiki/Wiki#Linking_and_creating_pages
# #Searching
# https://en.wikipedia.org/wiki/Wiki#Searching
# #History
# https://en.wikipedia.org/wiki/Wiki#History
# #Alternative_definitions
# https://en.wikipedia.org/wiki/Wiki#Alternative_definitions
# #Implementations
# https://en.wikipedia.org/wiki/Wiki#Implementations
# #Trust_and_security
# https://en.wikipedia.org/wiki/Wiki#Trust_and_security
# #Controlling_changes
# https://en.wikipedia.org/wiki/Wiki#Controlling_changes
# #Trustworthiness_and_reliability_of_content
# https://en.wikipedia.org/wiki/Wiki#Trustworthiness_and_reliability_of_content
# #Security
# https://en.wikipedia.org/wiki/Wiki#Security
# #Potential_malware_vector
# https://en.wikipedia.org/wiki/Wiki#Potential_malware_vector
# #Communities
# https://en.wikipedia.org/wiki/Wiki#Communities
# #Applications
# https://en.wikipedia.org/wiki/Wiki#Applications
# #City_wikis
# https://en.wikipedia.org/wiki/Wiki#City_wikis
# #WikiNodes
# https://en.wikipedia.org/wiki/Wiki#WikiNodes
# #Participants
# https://en.wikipedia.org/wiki/Wiki#Participants
# #Growth_factors
# https://en.wikipedia.org/wiki/Wiki#Growth_factors
# #Conferences
# https://en.wikipedia.org/wiki/Wiki#Conferences
# #Rules
# https://en.wikipedia.org/wiki/Wiki#Rules
# #Legal_environment
# https://en.wikipedia.org/wiki/Wiki#Legal_environment
# #See_also
# https://en.wikipedia.org/wiki/Wiki#See_also
# #Notes
# https://en.wikipedia.org/wiki/Wiki#Notes
# #References
# https://en.wikipedia.org/wiki/Wiki#References
# #Further_reading
# https://en.wikipedia.org/wiki/Wiki#Further_reading
# #External_links
# https://en.wikipedia.org/wiki/Wiki#External_links
# /wiki/File:Question_book-new.svg
# https://en.wikipedia.org/wiki/File:Question_book-new.svg
# /wiki/Wikipedia:Verifiability
# https://en.wikipedia.org/wiki/Wikipedia:Verifiability
# https://en.wikipedia.org/w/index.php?title=Wiki&action=edit
# /wiki/Help:Referencing_for_beginners
# https://en.wikipedia.org/wiki/Help:Referencing_for_beginners
# /wiki/Help:Maintenance_template_removal
# https://en.wikipedia.org/wiki/Help:Maintenance_template_removal
# /wiki/File:Ward_Cunningham_-_Commons-1.jpg
# https://en.wikipedia.org/wiki/File:Ward_Cunningham_-_Commons-1.jpg
# /wiki/File:Ward_Cunningham_-_Commons-1.jpg
# https://en.wikipedia.org/wiki/File:Ward_Cunningham_-_Commons-1.jpg
# /wiki/Ward_Cunningham
# https://en.wikipedia.org/wiki/Ward_Cunningham
# /wiki/Bo_Leuf
# https://en.wikipedia.org/wiki/Bo_Leuf
# /wiki/The_Wiki_Way
# https://en.wikipedia.org/wiki/The_Wiki_Way
# #cite_note-9
# https://en.wikipedia.org/wiki/Wiki#cite_note-9
# /wiki/Web_page
# https://en.wikipedia.org/wiki/Web_page
# /wiki/Vanilla_software
# https://en.wikipedia.org/wiki/Vanilla_software
# /wiki/Browser_extension
# https://en.wikipedia.org/wiki/Browser_extension
# /wiki/Internet
# https://en.wikipedia.org/wiki/Internet
# /wiki/Web_browser
# https://en.wikipedia.org/wiki/Web_browser
# /wiki/Simple_markup_language
# https://en.wikipedia.org/wiki/Simple_markup_language
# /wiki/MediaWiki_markup_language
# https://en.wikipedia.org/wiki/MediaWiki_markup_language
# /wiki/Hyperlink
# https://en.wikipedia.org/wiki/Hyperlink
# #cite_note-Legal-10
# https://en.wikipedia.org/wiki/Wiki#cite_note-Legal-10
# /wiki/User_(computing)
# https://en.wikipedia.org/wiki/User_(computing)
# /wiki/Real-time_web
# https://en.wikipedia.org/wiki/Real-time_web
# /wiki/Authentication
# https://en.wikipedia.org/wiki/Authentication
# /wiki/Maged_N._Kamel_Boulos
# https://en.wikipedia.org/wiki/Maged_N._Kamel_Boulos
# /wiki/Steve_Wheeler
# https://en.wikipedia.org/wiki/Steve_Wheeler
# /wiki/Social_Darwinism
# https://en.wikipedia.org/wiki/Social_Darwinism
# #cite_note-BMC-11
# https://en.wikipedia.org/wiki/Wiki#cite_note-BMC-11
# /wiki/Help:Wikitext
# https://en.wikipedia.org/wiki/Help:Wikitext
# /wiki/Help:Wikitext
# https://en.wikipedia.org/wiki/Help:Wikitext
# /wiki/Help:Cheatsheet
# https://en.wikipedia.org/wiki/Help:Cheatsheet
# /wiki/Help:Wikitext
# https://en.wikipedia.org/wiki/Help:Wikitext
# /wiki/Help:Magic_links
# https://en.wikipedia.org/wiki/Help:Magic_links
# /wiki/Help:Visual_file_markup
# https://en.wikipedia.org/wiki/Help:Visual_file_markup
# /wiki/Help:Sound_file_markup
# https://en.wikipedia.org/wiki/Help:Sound_file_markup
# /wiki/Help:Table
# https://en.wikipedia.org/wiki/Help:Table
# /wiki/Help:A_quick_guide_to_templates
# https://en.wikipedia.org/wiki/Help:A_quick_guide_to_templates
# /wiki/Help:HTML_in_wikitext
# https://en.wikipedia.org/wiki/Help:HTML_in_wikitext
# /wiki/Template:Wikitext_navbox
# https://en.wikipedia.org/wiki/Template:Wikitext_navbox
# /wiki/Template_talk:Wikitext_navbox
# https://en.wikipedia.org/wiki/Template_talk:Wikitext_navbox
# https://en.wikipedia.org/w/index.php?title=Template:Wikitext_navbox&action=edit
# /wiki/WYSIWYG
# https://en.wikipedia.org/wiki/WYSIWYG
# #Visual_editing
# https://en.wikipedia.org/wiki/Wiki#Visual_editing
# /wiki/Asterisk
# https://en.wikipedia.org/wiki/Asterisk
# /wiki/Bullet_(typography)
# https://en.wikipedia.org/wiki/Bullet_(typography)
# /wiki/Wikipedia:AUDIENCE
# https://en.wikipedia.org/wiki/Wikipedia:AUDIENCE
# /wiki/HTML_tag
# https://en.wikipedia.org/wiki/HTML_tag
# /wiki/Cascading_Style_Sheets
# https://en.wikipedia.org/wiki/Cascading_Style_Sheets
# /wiki/JavaScript
# https://en.wikipedia.org/wiki/JavaScript
# /wiki/MediaWiki
# https://en.wikipedia.org/wiki/MediaWiki
# /wiki/Tea
# https://en.wikipedia.org/wiki/Tea
# /wiki/WYSIWYG
# https://en.wikipedia.org/wiki/WYSIWYG
# /wiki/HTML_element
# https://en.wikipedia.org/wiki/HTML_element
# /wiki/Transparency_(human-computer_interaction)
# https://en.wikipedia.org/wiki/Transparency_(human-computer_interaction)
# /wiki/VisualEditor
# https://en.wikipedia.org/wiki/VisualEditor
# /wiki/Help:Edit_summary
# https://en.wikipedia.org/wiki/Help:Edit_summary
# /wiki/MediaWiki
# https://en.wikipedia.org/wiki/MediaWiki
# /wiki/Wikipedia
# https://en.wikipedia.org/wiki/Wikipedia
# /wiki/Revision_control
# https://en.wikipedia.org/wiki/Revision_control
# /wiki/Hypertext
# https://en.wikipedia.org/wiki/Hypertext
# /wiki/Ad_hoc
# https://en.wikipedia.org/wiki/Ad_hoc
# /wiki/Backlink
# https://en.wikipedia.org/wiki/Backlink
# /wiki/Cold_weather_cycling
# https://en.wikipedia.org/wiki/Cold_weather_cycling
# /wiki/Wikipedia:Citation_needed
# https://en.wikipedia.org/wiki/Wikipedia:Citation_needed
# /wiki/CamelCase
# https://en.wikipedia.org/wiki/CamelCase
# /wiki/Capital_letter
# https://en.wikipedia.org/wiki/Capital_letter
# /wiki/Search_algorithm
# https://en.wikipedia.org/wiki/Search_algorithm
# /wiki/Full_text_search
# https://en.wikipedia.org/wiki/Full_text_search
# /wiki/PmWiki
# https://en.wikipedia.org/wiki/PmWiki
# /wiki/Flat_file
# https://en.wikipedia.org/wiki/Flat_file
# #cite_note-Augar-12
# https://en.wikipedia.org/wiki/Wiki#cite_note-Augar-12
# /wiki/Lee_Daniel_Crocker
# https://en.wikipedia.org/wiki/Lee_Daniel_Crocker
# /wiki/Wikipedia:Citation_needed
# https://en.wikipedia.org/wiki/Wikipedia:Citation_needed
# /wiki/Web_search_engine
# https://en.wikipedia.org/wiki/Web_search_engine
# /wiki/Google_Search
# https://en.wikipedia.org/wiki/Google_Search
# /wiki/History_of_wikis
# https://en.wikipedia.org/wiki/History_of_wikis
# /wiki/File:HNL_Wiki_Wiki_Bus.jpg
# https://en.wikipedia.org/wiki/File:HNL_Wiki_Wiki_Bus.jpg
# /wiki/File:HNL_Wiki_Wiki_Bus.jpg
# https://en.wikipedia.org/wiki/File:HNL_Wiki_Wiki_Bus.jpg
# /wiki/Wiki_Wiki_Shuttle
# https://en.wikipedia.org/wiki/Wiki_Wiki_Shuttle
# /wiki/Honolulu_International_Airport
# https://en.wikipedia.org/wiki/Honolulu_International_Airport
# /wiki/WikiWikiWeb
# https://en.wikipedia.org/wiki/WikiWikiWeb
# #cite_note-ebersbach10-13
# https://en.wikipedia.org/wiki/Wiki#cite_note-ebersbach10-13
# /wiki/Domain_name
# https://en.wikipedia.org/wiki/Domain_name
# /wiki/C2.com
# https://en.wikipedia.org/wiki/C2.com
# /wiki/Honolulu_International_Airport
# https://en.wikipedia.org/wiki/Honolulu_International_Airport
# /wiki/Wiki_Wiki_Shuttle
# https://en.wikipedia.org/wiki/Wiki_Wiki_Shuttle
# #cite_note-cunningham-14
# https://en.wikipedia.org/wiki/Wiki#cite_note-cunningham-14
# #cite_note-history-15
# https://en.wikipedia.org/wiki/Wiki#cite_note-history-15
# /wiki/Apple_Inc.
# https://en.wikipedia.org/wiki/Apple_Inc.
# /wiki/HyperCard
# https://en.wikipedia.org/wiki/HyperCard
# #cite_note-artima-16
# https://en.wikipedia.org/wiki/Wiki#cite_note-artima-16
# /wiki/Vannevar_Bush
# https://en.wikipedia.org/wiki/Vannevar_Bush
# #cite_note-Britannica-2
# https://en.wikipedia.org/wiki/Wiki#cite_note-Britannica-2
# #cite_note-hypercard-17
# https://en.wikipedia.org/wiki/Wiki#cite_note-hypercard-17
# /wiki/Pattern_language
# https://en.wikipedia.org/wiki/Pattern_language
# #cite_note-artima-16
# https://en.wikipedia.org/wiki/Wiki#cite_note-artima-16
# /wiki/Wikipedia
# https://en.wikipedia.org/wiki/Wikipedia
# /wiki/Corporate_wiki
# https://en.wikipedia.org/wiki/Corporate_wiki
# /wiki/Group_learning
# https://en.wikipedia.org/wiki/Group_learning
# /wiki/Firewall_(computing)
# https://en.wikipedia.org/wiki/Firewall_(computing)
# /wiki/Oxford_English_Dictionary
# https://en.wikipedia.org/wiki/Oxford_English_Dictionary
# #cite_note-OED1-18
# https://en.wikipedia.org/wiki/Wiki#cite_note-OED1-18
# #cite_note-Easy_Wiki_Hosting-1
# https://en.wikipedia.org/wiki/Wiki#cite_note-Easy_Wiki_Hosting-1
# #cite_note-19
# https://en.wikipedia.org/wiki/Wiki#cite_note-19
# /wiki/Distributed_version_control
# https://en.wikipedia.org/wiki/Distributed_version_control
# #cite_note-20
# https://en.wikipedia.org/wiki/Wiki#cite_note-20
# /wiki/List_of_wiki_software
# https://en.wikipedia.org/wiki/List_of_wiki_software
# /wiki/Wiki_software
# https://en.wikipedia.org/wiki/Wiki_software
# /wiki/Collaborative_software
# https://en.wikipedia.org/wiki/Collaborative_software
# /wiki/Web_server
# https://en.wikipedia.org/wiki/Web_server
# /wiki/Application_server
# https://en.wikipedia.org/wiki/Application_server
# /wiki/File_system
# https://en.wikipedia.org/wiki/File_system
# /wiki/Relational_database_management_system
# https://en.wikipedia.org/wiki/Relational_database_management_system
# /wiki/MediaWiki
# https://en.wikipedia.org/wiki/MediaWiki
# /wiki/Wikipedia
# https://en.wikipedia.org/wiki/Wikipedia
# /wiki/Personal_wiki
# https://en.wikipedia.org/wiki/Personal_wiki
# /wiki/Wiki_farm
# https://en.wikipedia.org/wiki/Wiki_farm
# /wiki/Comparison_of_wiki_farms
# https://en.wikipedia.org/wiki/Comparison_of_wiki_farms
# /wiki/Help:Recent_changes
# https://en.wikipedia.org/wiki/Help:Recent_changes
# /wiki/Special:RecentChanges
# https://en.wikipedia.org/wiki/Special:RecentChanges
# /wiki/File:History_Comparison_Example_(Vector).png
# https://en.wikipedia.org/wiki/File:History_Comparison_Example_(Vector).png
# /wiki/File:History_Comparison_Example_(Vector).png
# https://en.wikipedia.org/wiki/File:History_Comparison_Example_(Vector).png
# #cite_note-21
# https://en.wikipedia.org/wiki/Wiki#cite_note-21
# /wiki/Internet_bot
# https://en.wikipedia.org/wiki/Internet_bot
# #cite_note-22
# https://en.wikipedia.org/wiki/Wiki#cite_note-22
# /wiki/Changelog
# https://en.wikipedia.org/wiki/Changelog
# /wiki/Diff
# https://en.wikipedia.org/wiki/Diff
# #cite_note-23
# https://en.wikipedia.org/wiki/Wiki#cite_note-23
# #cite_note-24
# https://en.wikipedia.org/wiki/Wiki#cite_note-24
# #cite_note-25
# https://en.wikipedia.org/wiki/Wiki#cite_note-25
# #cite_note-Britannica-2
# https://en.wikipedia.org/wiki/Wiki#cite_note-Britannica-2
# /wiki/Lars_Aronsson
# https://en.wikipedia.org/wiki/Lars_Aronsson
# /wiki/Graffiti
# https://en.wikipedia.org/wiki/Graffiti
# #cite_note-ebersbach10-13
# https://en.wikipedia.org/wiki/Wiki#cite_note-ebersbach10-13
# #cite_note-26
# https://en.wikipedia.org/wiki/Wiki#cite_note-26
# #cite_note-27
# https://en.wikipedia.org/wiki/Wiki#cite_note-27
# #cite_note-Noveck-28
# https://en.wikipedia.org/wiki/Wiki#cite_note-Noveck-28
# /wiki/Edit_conflict
# https://en.wikipedia.org/wiki/Edit_conflict
# /wiki/Wikipedia:Edit_warring
# https://en.wikipedia.org/wiki/Wikipedia:Edit_warring
# /wiki/Cybervandalism
# https://en.wikipedia.org/wiki/Cybervandalism
# /wiki/Hoax
# https://en.wikipedia.org/wiki/Hoax
# /wiki/Wikimedia_Foundation
# https://en.wikipedia.org/wiki/Wikimedia_Foundation
# /wiki/Vandalism
# https://en.wikipedia.org/wiki/Vandalism
# /wiki/Troll_(Internet)
# https://en.wikipedia.org/wiki/Troll_(Internet)
# /wiki/Soft_security
# https://en.wikipedia.org/wiki/Soft_security
# #cite_note-29
# https://en.wikipedia.org/wiki/Wiki#cite_note-29
# /wiki/Wikipedia:Reliable_sources
# https://en.wikipedia.org/wiki/Wikipedia:Reliable_sources
# /wiki/Machine_learning
# https://en.wikipedia.org/wiki/Machine_learning
# /wiki/Heuristic_(computer_science)
# https://en.wikipedia.org/wiki/Heuristic_(computer_science)
# #cite_note-30
# https://en.wikipedia.org/wiki/Wiki#cite_note-30
# /wiki/IP_address
# https://en.wikipedia.org/wiki/IP_address
# #cite_note-31
# https://en.wikipedia.org/wiki/Wiki#cite_note-31
# #cite_note-Legal-10
# https://en.wikipedia.org/wiki/Wiki#cite_note-Legal-10
# #cite_note-Augar-12
# https://en.wikipedia.org/wiki/Wiki#cite_note-Augar-12
# /wiki/Malware
# https://en.wikipedia.org/wiki/Malware
# /wiki/Blaster_Worm
# https://en.wikipedia.org/wiki/Blaster_Worm
# #cite_note-Legal-10
# https://en.wikipedia.org/wiki/Wiki#cite_note-Legal-10
# /wiki/Blacklist
# https://en.wikipedia.org/wiki/Blacklist
# #cite_note-32
# https://en.wikipedia.org/wiki/Wiki#cite_note-32
# /wiki/File:EnglishWikipedia_29June2017.png
# https://en.wikipedia.org/wiki/File:EnglishWikipedia_29June2017.png
# /wiki/File:EnglishWikipedia_29June2017.png
# https://en.wikipedia.org/wiki/File:EnglishWikipedia_29June2017.png
# /wiki/World_Wide_Web
# https://en.wikipedia.org/wiki/World_Wide_Web
# #cite_note-33
# https://en.wikipedia.org/wiki/Wiki#cite_note-33
# #cite_note-34
# https://en.wikipedia.org/wiki/Wiki#cite_note-34
# /wiki/WikiWikiWeb
# https://en.wikipedia.org/wiki/WikiWikiWeb
# /wiki/Memory_Alpha
# https://en.wikipedia.org/wiki/Memory_Alpha
# /wiki/Wikivoyage
# https://en.wikipedia.org/wiki/Wikivoyage
# /wiki/Susning.nu
# https://en.wikipedia.org/wiki/Susning.nu
# /wiki/List_of_medical_wikis
# https://en.wikipedia.org/wiki/List_of_medical_wikis
# /wiki/Ganfyd
# https://en.wikipedia.org/wiki/Ganfyd
# #cite_note-BMC-11
# https://en.wikipedia.org/wiki/Wiki#cite_note-BMC-11
# /wiki/Online_community
# https://en.wikipedia.org/wiki/Online_community
# /wiki/Enterprise_software
# https://en.wikipedia.org/wiki/Enterprise_software
# /wiki/Internal_documentation
# https://en.wikipedia.org/wiki/Internal_documentation
# #cite_note-35
# https://en.wikipedia.org/wiki/Wiki#cite_note-35
# #cite_note-36
# https://en.wikipedia.org/wiki/Wiki#cite_note-36
# #cite_note-37
# https://en.wikipedia.org/wiki/Wiki#cite_note-37
# #cite_note-38
# https://en.wikipedia.org/wiki/Wiki#cite_note-38
# /wiki/Wikipedia:Manual_of_Style/Dates_and_numbers#Chronological_items
# https://en.wikipedia.org/wiki/Wikipedia:Manual_of_Style/Dates_and_numbers#Chronological_items
# /wiki/Project_management
# https://en.wikipedia.org/wiki/Project_management
# #cite_note-39
# https://en.wikipedia.org/wiki/Wiki#cite_note-39
# #cite_note-40
# https://en.wikipedia.org/wiki/Wiki#cite_note-40
# /wiki/Wikipedia:Reliable_sources
# https://en.wikipedia.org/wiki/Wikipedia:Reliable_sources
# #cite_note-41
# https://en.wikipedia.org/wiki/Wiki#cite_note-41
# /wiki/Grant_writing
# https://en.wikipedia.org/wiki/Grant_writing
# /wiki/Strategic_planning
# https://en.wikipedia.org/wiki/Strategic_planning
# #cite_note-42
# https://en.wikipedia.org/wiki/Wiki#cite_note-42
# #cite_note-Legal-10
# https://en.wikipedia.org/wiki/Wiki#cite_note-Legal-10
# /wiki/Central_Intelligence_Agency
# https://en.wikipedia.org/wiki/Central_Intelligence_Agency
# /wiki/Intellipedia
# https://en.wikipedia.org/wiki/Intellipedia
# /wiki/Intelligence_assessment
# https://en.wikipedia.org/wiki/Intelligence_assessment
# /wiki/American_Civil_Liberties_Union
# https://en.wikipedia.org/wiki/American_Civil_Liberties_Union
# /wiki/Guant%C3%A1namo_Bay
# https://en.wikipedia.org/wiki/Guant%C3%A1namo_Bay
# #cite_note-43
# https://en.wikipedia.org/wiki/Wiki#cite_note-43
# /wiki/United_States_Court_of_Appeals_for_the_Seventh_Circuit
# https://en.wikipedia.org/wiki/United_States_Court_of_Appeals_for_the_Seventh_Circuit
# /wiki/United_States_Patent_and_Trademark_Office
# https://en.wikipedia.org/wiki/United_States_Patent_and_Trademark_Office
# /wiki/Peer-to-Patent
# https://en.wikipedia.org/wiki/Peer-to-Patent
# /wiki/Prior_art
# https://en.wikipedia.org/wiki/Prior_art
# /wiki/Queens
# https://en.wikipedia.org/wiki/Queens
# /wiki/Cornell_Law_School
# https://en.wikipedia.org/wiki/Cornell_Law_School
# #cite_note-Noveck-28
# https://en.wikipedia.org/wiki/Wiki#cite_note-Noveck-28
# #cite_note-44
# https://en.wikipedia.org/wiki/Wiki#cite_note-44
# #cite_note-45
# https://en.wikipedia.org/wiki/Wiki#cite_note-45
# /wiki/Knowledge_management
# https://en.wikipedia.org/wiki/Knowledge_management
# /wiki/Social_network
# https://en.wikipedia.org/wiki/Social_network
# /wiki/Geography
# https://en.wikipedia.org/wiki/Geography
# #cite_note-46
# https://en.wikipedia.org/wiki/Wiki#cite_note-46
# #cite_note-47
# https://en.wikipedia.org/wiki/Wiki#cite_note-47
# #cite_note-48
# https://en.wikipedia.org/wiki/Wiki#cite_note-48
# /wiki/Encyclopedia
# https://en.wikipedia.org/wiki/Encyclopedia
# /wiki/Wikipedia
# https://en.wikipedia.org/wiki/Wikipedia
# /wiki/Wikipedia:WikiNode
# https://en.wikipedia.org/wiki/Wikipedia:WikiNode
# /wiki/WikiNodes
# https://en.wikipedia.org/wiki/WikiNodes
# //upload.wikimedia.org/wikipedia/commons/6/6a/Development_of_%22Mathe_f%C3%BCr_Nicht-Freaks%22_from_Sep_2009_to_June_2016.webm
# https://upload.wikimedia.org/wikipedia/commons/6/6a/Development_of_%22Mathe_f%C3%BCr_Nicht-Freaks%22_from_Sep_2009_to_June_2016.webm
# /wiki/File:Development_of_%22Mathe_f%C3%BCr_Nicht-Freaks%22_from_Sep_2009_to_June_2016.webm
# https://en.wikipedia.org/wiki/File:Development_of_%22Mathe_f%C3%BCr_Nicht-Freaks%22_from_Sep_2009_to_June_2016.webm
# https://en.wikibooks.org/wiki/de:Mathe_f%C3%BCr_Nicht-Freaks
# #cite_note-49
# https://en.wikipedia.org/wiki/Wiki#cite_note-49
# /wiki/Wikipedia:TourBusStop
# https://en.wikipedia.org/wiki/Wikipedia:TourBusStop
# #cite_note-50
# https://en.wikipedia.org/wiki/Wiki#cite_note-50
# #cite_note-51
# https://en.wikipedia.org/wiki/Wiki#cite_note-51
# #cite_note-52
# https://en.wikipedia.org/wiki/Wiki#cite_note-52
# /wiki/Atlassian
# https://en.wikipedia.org/wiki/Atlassian
# /wiki/Confluence_(software)
# https://en.wikipedia.org/wiki/Confluence_(software)
# #cite_note-53
# https://en.wikipedia.org/wiki/Wiki#cite_note-53
# /wiki/OpenSym
# https://en.wikipedia.org/wiki/OpenSym
# /wiki/Academic_conference
# https://en.wikipedia.org/wiki/Academic_conference
# /wiki/Semantic_MediaWiki
# https://en.wikipedia.org/wiki/Semantic_MediaWiki
# #cite_note-54
# https://en.wikipedia.org/wiki/Wiki#cite_note-54
# /wiki/Tiki_Wiki_CMS_Groupware
# https://en.wikipedia.org/wiki/Tiki_Wiki_CMS_Groupware
# #cite_note-55
# https://en.wikipedia.org/wiki/Wiki#cite_note-55
# /wiki/Wikimania
# https://en.wikipedia.org/wiki/Wikimania
# /wiki/Wikimedia_Foundation
# https://en.wikipedia.org/wiki/Wikimedia_Foundation
# /wiki/RecentChangesCamp
# https://en.wikipedia.org/wiki/RecentChangesCamp
# /wiki/Unconference
# https://en.wikipedia.org/wiki/Unconference
# #cite_note-56
# https://en.wikipedia.org/wiki/Wiki#cite_note-56
# /wiki/Conservapedia
# https://en.wikipedia.org/wiki/Conservapedia
# /wiki/Before_Christ
# https://en.wikipedia.org/wiki/Before_Christ
# /wiki/B.C.E.
# https://en.wikipedia.org/wiki/B.C.E.
# /wiki/Common_Era
# https://en.wikipedia.org/wiki/Common_Era
# #cite_note-57
# https://en.wikipedia.org/wiki/Wiki#cite_note-57
# /wiki/The_Golden_Rule
# https://en.wikipedia.org/wiki/The_Golden_Rule
# #cite_note-Augar-12
# https://en.wikipedia.org/wiki/Wiki#cite_note-Augar-12
# /wiki/Tenants_in_common
# https://en.wikipedia.org/wiki/Tenants_in_common
# #cite_note-Legal-10
# https://en.wikipedia.org/wiki/Wiki#cite_note-Legal-10
# /wiki/Collective_work
# https://en.wikipedia.org/wiki/Collective_work
# #cite_note-58
# https://en.wikipedia.org/wiki/Wiki#cite_note-58
# /wiki/Open_content
# https://en.wikipedia.org/wiki/Open_content
# /wiki/GNU_Free_Documentation_License
# https://en.wikipedia.org/wiki/GNU_Free_Documentation_License
# /wiki/Creative_Commons
# https://en.wikipedia.org/wiki/Creative_Commons
# /wiki/Wikipedia:Citation_needed
# https://en.wikipedia.org/wiki/Wikipedia:Citation_needed
# #cite_note-Legal-10
# https://en.wikipedia.org/wiki/Wiki#cite_note-Legal-10
# /wiki/Section_230_of_the_Communications_Decency_Act
# https://en.wikipedia.org/wiki/Section_230_of_the_Communications_Decency_Act
# /wiki/Good_Samaritan
# https://en.wikipedia.org/wiki/Good_Samaritan
# #cite_note-59
# https://en.wikipedia.org/wiki/Wiki#cite_note-59
# #cite_note-60
# https://en.wikipedia.org/wiki/Wiki#cite_note-60
# /wiki/Defamation
# https://en.wikipedia.org/wiki/Defamation
# /wiki/Internet_service_provider
# https://en.wikipedia.org/wiki/Internet_service_provider
# #cite_note-Legal-10
# https://en.wikipedia.org/wiki/Wiki#cite_note-Legal-10
# #cite_note-61
# https://en.wikipedia.org/wiki/Wiki#cite_note-61
# /wiki/File:Crystal_Clear_app_linneighborhood.svg
# https://en.wikipedia.org/wiki/File:Crystal_Clear_app_linneighborhood.svg
# /wiki/Portal:Internet
# https://en.wikipedia.org/wiki/Portal:Internet
# /wiki/Comparison_of_wiki_software
# https://en.wikipedia.org/wiki/Comparison_of_wiki_software
# /wiki/Content_management_system
# https://en.wikipedia.org/wiki/Content_management_system
# /wiki/CURIE
# https://en.wikipedia.org/wiki/CURIE
# /wiki/Dispersed_knowledge
# https://en.wikipedia.org/wiki/Dispersed_knowledge
# /wiki/List_of_wikis
# https://en.wikipedia.org/wiki/List_of_wikis
# /wiki/Mass_collaboration
# https://en.wikipedia.org/wiki/Mass_collaboration
# /wiki/Universal_Edit_Button
# https://en.wikipedia.org/wiki/Universal_Edit_Button
# /wiki/Wikis_and_education
# https://en.wikipedia.org/wiki/Wikis_and_education
# #cite_ref-5
# https://en.wikipedia.org/wiki/Wiki#cite_ref-5
# /wiki/Phoneme
# https://en.wikipedia.org/wiki/Phoneme
# /wiki/Hawaiian_phonology
# https://en.wikipedia.org/wiki/Hawaiian_phonology
# #cite_ref-Easy_Wiki_Hosting_1-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Easy_Wiki_Hosting_1-0
# #cite_ref-Easy_Wiki_Hosting_1-1
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Easy_Wiki_Hosting_1-1
# http://msdn.microsoft.com/en-us/magazine/cc700339.aspx
# https://web.archive.org/web/20100316192702/http://msdn.microsoft.com/en-us/magazine/cc700339.aspx
# #cite_ref-Britannica_2-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Britannica_2-0
# #cite_ref-Britannica_2-1
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Britannica_2-1
# #cite_ref-Britannica_2-2
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Britannica_2-2
# http://www.britannica.com/EBchecked/topic/1192819/wiki
# /wiki/Encyclop%C3%A6dia_Britannica
# https://en.wikipedia.org/wiki/Encyclop%C3%A6dia_Britannica
# /wiki/Encyclop%C3%A6dia_Britannica,_Inc.
# https://en.wikipedia.org/wiki/Encyclop%C3%A6dia_Britannica,_Inc.
# https://web.archive.org/web/20080424074513/http://www.britannica.com/EBchecked/topic/1192819/wiki
# #cite_ref-Alexa_Top_Sites_3-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Alexa_Top_Sites_3-0
# http://www.alexa.com/topsites
# https://web.archive.org/web/20150302173920/http://www.alexa.com/topsites
# #cite_ref-4
# https://en.wikipedia.org/wiki/Wiki#cite_ref-4
# /wiki/Ward_Cunningham
# https://en.wikipedia.org/wiki/Ward_Cunningham
# http://www.wiki.org/wiki.cgi?WhatIsWiki
# https://web.archive.org/web/20080416212802/http://www.wiki.org/wiki.cgi?WhatIsWiki
# #cite_ref-6
# https://en.wikipedia.org/wiki/Wiki#cite_ref-6
# http://www.mauimapp.com/moolelo/hwnwdshw.htm
# https://web.archive.org/web/20080914154748/http://www.mauimapp.com/moolelo/hwnwdshw.htm
# #cite_ref-7
# https://en.wikipedia.org/wiki/Wiki#cite_ref-7
# https://archive.org/details/wikipedia35milli0000hasa/page/11
# https://archive.org/details/wikipedia35milli0000hasa/page/11
# /wiki/ISBN_(identifier)
# https://en.wikipedia.org/wiki/ISBN_(identifier)
# /wiki/Special:BookSources/9781448855575
# https://en.wikipedia.org/wiki/Special:BookSources/9781448855575
# https://web.archive.org/web/20191026122531/https://archive.org/details/wikipedia35milli0000hasa/page/11
# #cite_ref-8
# https://en.wikipedia.org/wiki/Wiki#cite_ref-8
# https://archive.org/details/dictionaryofhawa00andrrich/
# https://web.archive.org/web/20140815064248/https://archive.org/details/dictionaryofhawa00andrrich/
# #cite_ref-9
# https://en.wikipedia.org/wiki/Wiki#cite_ref-9
# #CITEREFLeufCunningham2001
# https://en.wikipedia.org/wiki/Wiki#CITEREFLeufCunningham2001
# http://c2.com/cgi/wiki?WikiDesignPrinciples
# https://web.archive.org/web/20020430181259/http://c2.com/cgi/wiki?WikiDesignPrinciples
# /wiki/Category:CS1_maint:_archived_copy_as_title
# https://en.wikipedia.org/wiki/Category:CS1_maint:_archived_copy_as_title
# #cite_ref-Legal_10-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Legal_10-0
# #cite_ref-Legal_10-1
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Legal_10-1
# #cite_ref-Legal_10-2
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Legal_10-2
# #cite_ref-Legal_10-3
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Legal_10-3
# #cite_ref-Legal_10-4
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Legal_10-4
# #cite_ref-Legal_10-5
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Legal_10-5
# #cite_ref-Legal_10-6
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Legal_10-6
# https://web.archive.org/web/20121222125337/https://elaw.murdoch.edu.au/archives/issues/2007/1/eLaw_legal%20issues%20for%20wikis.pdf
# https://elaw.murdoch.edu.au/archives/issues/2007/1/eLaw_legal%20issues%20for%20wikis.pdf
# #cite_ref-BMC_11-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-BMC_11-0
# #cite_ref-BMC_11-1
# https://en.wikipedia.org/wiki/Wiki#cite_ref-BMC_11-1
# /wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://doi.org/10.1186%2F1472-6920-6-41
# /wiki/PMC_(identifier)
# https://en.wikipedia.org/wiki/PMC_(identifier)
# //www.ncbi.nlm.nih.gov/pmc/articles/PMC1564136
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1564136
# /wiki/PMID_(identifier)
# https://en.wikipedia.org/wiki/PMID_(identifier)
# //pubmed.ncbi.nlm.nih.gov/16911779
# https://pubmed.ncbi.nlm.nih.gov/16911779
# #cite_ref-Augar_12-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Augar_12-0
# #cite_ref-Augar_12-1
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Augar_12-1
# #cite_ref-Augar_12-2
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Augar_12-2
# /wiki/CiteSeerX_(identifier)
# https://en.wikipedia.org/wiki/CiteSeerX_(identifier)
# //citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.133.1456
# https://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.133.1456
# /wiki/Help:CS1_errors#missing_periodical
# https://en.wikipedia.org/wiki/Help:CS1_errors#missing_periodical
# #cite_ref-ebersbach10_13-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-ebersbach10_13-0
# #cite_ref-ebersbach10_13-1
# https://en.wikipedia.org/wiki/Wiki#cite_ref-ebersbach10_13-1
# #CITEREFEbersbach2008
# https://en.wikipedia.org/wiki/Wiki#CITEREFEbersbach2008
# #cite_ref-cunningham_14-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-cunningham_14-0
# http://c2.com/doc/etymology.html
# https://web.archive.org/web/20070317120823/http://c2.com/doc/etymology.html
# #cite_ref-history_15-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-history_15-0
# http://c2.com/cgi/wiki?WikiHistory
# https://web.archive.org/web/20020621221535/http://c2.com/cgi/wiki?WikiHistory
# #cite_ref-artima_16-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-artima_16-0
# #cite_ref-artima_16-1
# https://en.wikipedia.org/wiki/Wiki#cite_ref-artima_16-1
# http://www.artima.com/intv/wiki.html
# https://web.archive.org/web/20150205091836/http://www.artima.com/intv/wiki.html
# #cite_ref-hypercard_17-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-hypercard_17-0
# http://c2.com/cgi/wiki?WikiWikiHyperCard
# https://web.archive.org/web/20070406064446/http://c2.com/cgi/wiki?WikiWikiHyperCard
# #cite_ref-OED1_18-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-OED1_18-0
# http://www.oed.com/public/update0703/march-2007-update
# /wiki/Oxford_English_Dictionary
# https://en.wikipedia.org/wiki/Oxford_English_Dictionary
# https://web.archive.org/web/20110107132110/http://www.oed.com/public/update0703/march-2007-update
# #cite_ref-19
# https://en.wikipedia.org/wiki/Wiki#cite_ref-19
# /wiki/Ward_Cunningham
# https://en.wikipedia.org/wiki/Ward_Cunningham
# https://twitter.com/WardCunningham/status/531149812976996352
# /wiki/Twitter
# https://en.wikipedia.org/wiki/Twitter
# #cite_ref-20
# https://en.wikipedia.org/wiki/Wiki#cite_ref-20
# http://forage.ward.fed.wiki.org/view/an-install-of-wiki
# https://web.archive.org/web/20150928165957/http://forage.ward.fed.wiki.org/view/an-install-of-wiki
# #cite_ref-21
# https://en.wikipedia.org/wiki/Wiki#cite_ref-21
# #CITEREFEbersbach2008
# https://en.wikipedia.org/wiki/Wiki#CITEREFEbersbach2008
# #cite_ref-22
# https://en.wikipedia.org/wiki/Wiki#cite_ref-22
# #CITEREFEbersbach2008
# https://en.wikipedia.org/wiki/Wiki#CITEREFEbersbach2008
# #cite_ref-23
# https://en.wikipedia.org/wiki/Wiki#cite_ref-23
# #CITEREFEbersbach2008
# https://en.wikipedia.org/wiki/Wiki#CITEREFEbersbach2008
# #cite_ref-24
# https://en.wikipedia.org/wiki/Wiki#cite_ref-24
# #CITEREFEbersbach2008
# https://en.wikipedia.org/wiki/Wiki#CITEREFEbersbach2008
# #cite_ref-25
# https://en.wikipedia.org/wiki/Wiki#cite_ref-25
# #cite_ref-26
# https://en.wikipedia.org/wiki/Wiki#cite_ref-26
# http://circle.ubc.ca/bitstream/handle/2429/497/c07-036.pdf
# /wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://doi.org/10.5596%2Fc07-036
# /wiki/ISSN_(identifier)
# https://en.wikipedia.org/wiki/ISSN_(identifier)
# //www.worldcat.org/issn/1708-6892
# https://www.worldcat.org/issn/1708-6892
# https://web.archive.org/web/20120430195019/https://circle.ubc.ca/bitstream/handle/2429/497/c07-036.pdf
# #cite_ref-27
# https://en.wikipedia.org/wiki/Wiki#cite_ref-27
# https://doi.org/10.1038%2F440278a
# /wiki/Bibcode_(identifier)
# https://en.wikipedia.org/wiki/Bibcode_(identifier)
# https://ui.adsabs.harvard.edu/abs/2006Natur.440..278Y
# /wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://doi.org/10.1038%2F440278a
# /wiki/PMID_(identifier)
# https://en.wikipedia.org/wiki/PMID_(identifier)
# //pubmed.ncbi.nlm.nih.gov/16541049
# https://pubmed.ncbi.nlm.nih.gov/16541049
# #cite_ref-Noveck_28-0
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Noveck_28-0
# #cite_ref-Noveck_28-1
# https://en.wikipedia.org/wiki/Wiki#cite_ref-Noveck_28-1
# http://heinonline.org/HOL/LandingPage?collection=journals&handle=hein.journals/jled57&div=8&id=&page=
# https://web.archive.org/web/20140703005842/http://heinonline.org/HOL/LandingPage?collection=journals&handle=hein.journals%2Fjled57&div=8&id=&page=
# #cite_ref-29
# https://en.wikipedia.org/wiki/Wiki#cite_ref-29
# https://web.archive.org/web/20140106040941/http://m3m.homelinux.org/wikiMC/index.php/Security
# http://m3m.homelinux.org/wikiMC/index.php/Security
# #cite_ref-30
# https://en.wikipedia.org/wiki/Wiki#cite_ref-30
# https://www.theverge.com/2014/2/18/5412636/this-machine-kills-trolls-how-wikipedia-robots-snuff-out-vandalism
# https://web.archive.org/web/20140827115824/http://www.theverge.com/2014/2/18/5412636/this-machine-kills-trolls-how-wikipedia-robots-snuff-out-vandalism
# #cite_ref-31
# https://en.wikipedia.org/wiki/Wiki#cite_ref-31
# #CITEREFEbersbach2008
# https://en.wikipedia.org/wiki/Wiki#CITEREFEbersbach2008
# #cite_ref-32
# https://en.wikipedia.org/wiki/Wiki#cite_ref-32
# https://meta.wikimedia.org/wiki/Spam_blacklist/About
# #cite_ref-33
# https://en.wikipedia.org/wiki/Wiki#cite_ref-33
# https://web.archive.org/web/20140825164715/http://s23.org/wikistats/largest_html.php?sort=users_desc&th=8000&lines=500
# http://s23.org/wikistats/largest_html.php?sort=users_desc&th=8000&lines=500
# #cite_ref-34
# https://en.wikipedia.org/wiki/Wiki#cite_ref-34
# http://www.alexa.com/topsites
# /wiki/Alexa_Internet
# https://en.wikipedia.org/wiki/Alexa_Internet
# https://web.archive.org/web/20150302173920/http://www.alexa.com/topsites
# #cite_ref-35
# https://en.wikipedia.org/wiki/Wiki#cite_ref-35
# https://web.archive.org/web/20110706095145/http://i-know.tugraz.at/wp-content/uploads/2008/11/47_wikis-for-collaborative-software-documentation.pdf
# http://i-know.tugraz.at/wp-content/uploads/2008/11/47_wikis-for-collaborative-software-documentation.pdf
# /wiki/Help:CS1_errors#missing_periodical
# https://en.wikipedia.org/wiki/Help:CS1_errors#missing_periodical
# #cite_ref-36
# https://en.wikipedia.org/wiki/Wiki#cite_ref-36
# /wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://doi.org/10.1145%2F1149453.1149472
# /wiki/ISBN_(identifier)
# https://en.wikipedia.org/wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-1-59593-413-0
# https://en.wikipedia.org/wiki/Special:BookSources/978-1-59593-413-0
# #cite_ref-37
# https://en.wikipedia.org/wiki/Wiki#cite_ref-37
# http://research.microsoft.com/apps/pubs/default.aspx?id=138573
# https://web.archive.org/web/20150904031729/http://research.microsoft.com/apps/pubs/default.aspx?id=138573
# #cite_ref-38
# https://en.wikipedia.org/wiki/Wiki#cite_ref-38
# http://www.businessweek.com/stories/2005-11-27/e-mail-is-so-five-minutes-ago
# https://web.archive.org/web/20121017131307/http://www.businessweek.com/stories/2005-11-27/e-mail-is-so-five-minutes-ago
# #cite_ref-39
# https://en.wikipedia.org/wiki/Wiki#cite_ref-39
# http://projectmanagementwiki.org
# https://web.archive.org/web/20140816221509/http://projectmanagementwiki.org/
# #cite_ref-40
# https://en.wikipedia.org/wiki/Wiki#cite_ref-40
# http://www.editme.com/Ways-to-Wiki-Project-Management
# https://web.archive.org/web/20120508152328/http://www.editme.com/Ways-to-Wiki-Project-Management
# #cite_ref-41
# https://en.wikipedia.org/wiki/Wiki#cite_ref-41
# http://portal.acm.org/citation.cfm?id=1142215.1142259
# /wiki/ISBN_(identifier)
# https://en.wikipedia.org/wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-2-84426-314-8
# https://en.wikipedia.org/wiki/Special:BookSources/978-2-84426-314-8
# #cite_ref-42
# https://en.wikipedia.org/wiki/Wiki#cite_ref-42
# /wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://doi.org/10.1080%2F02763860802114223
# /wiki/PMID_(identifier)
# https://en.wikipedia.org/wiki/PMID_(identifier)
# //pubmed.ncbi.nlm.nih.gov/18844087
# https://pubmed.ncbi.nlm.nih.gov/18844087
# #cite_ref-43
# https://en.wikipedia.org/wiki/Wiki#cite_ref-43
# https://www.dailykos.com/story/2005/06/09/120607/-SusanHu-s-FOIA-Project-UPDATE
# https://web.archive.org/web/20130530181455/http://www.dailykos.com/story/2005/06/09/120607/-SusanHu-s-FOIA-Project-UPDATE
# #cite_ref-44
# https://en.wikipedia.org/wiki/Wiki#cite_ref-44
# /wiki/Doi_(identifier)
# https://en.wikipedia.org/wiki/Doi_(identifier)
# https://doi.org/10.1109%2FIEEM.2017.8290296
# /wiki/ISBN_(identifier)
# https://en.wikipedia.org/wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-1-5386-0948-4
# https://en.wikipedia.org/wiki/Special:BookSources/978-1-5386-0948-4
# #cite_ref-45
# https://en.wikipedia.org/wiki/Wiki#cite_ref-45
# http://www.iaeng.org/publication/WCECS2014/WCECS2014_pp358-363.pdf
# https://web.archive.org/web/20190412152358/http://www.iaeng.org/publication/WCECS2014/WCECS2014_pp358-363.pdf
# #cite_ref-46
# https://en.wikipedia.org/wiki/Wiki#cite_ref-46
# http://www.niemanlab.org/2009/11/welcome-to-davis-calif-six-lessons-from-the-worlds-best-local-wiki/
# https://web.archive.org/web/20130808084426/http://www.niemanlab.org/2009/11/welcome-to-davis-calif-six-lessons-from-the-worlds-best-local-wiki/
# /wiki/Wayback_Machine
# https://en.wikipedia.org/wiki/Wayback_Machine
# #cite_ref-47
# https://en.wikipedia.org/wiki/Wiki#cite_ref-47
# http://www.niemanlab.org/2010/06/knight-news-challenge-is-a-wiki-site-coming-to-your-city-local-wiki-will-build-software-to-make-it-simple/
# https://web.archive.org/web/20130625035936/http://www.niemanlab.org/2010/06/knight-news-challenge-is-a-wiki-site-coming-to-your-city-local-wiki-will-build-software-to-make-it-simple/
# /wiki/Wayback_Machine
# https://en.wikipedia.org/wiki/Wayback_Machine
# #cite_ref-48
# https://en.wikipedia.org/wiki/Wiki#cite_ref-48
# /wiki/Wired_(magazine)
# https://en.wikipedia.org/wiki/Wired_(magazine)
# http://archive.wired.com/geekdad/2009/07/hey-kid-support-your-local-wiki/
# https://web.archive.org/web/20150427080359/http://archive.wired.com/geekdad/2009/07/hey-kid-support-your-local-wiki/
# /wiki/Wayback_Machine
# https://en.wikipedia.org/wiki/Wayback_Machine
# #cite_ref-49
# https://en.wikipedia.org/wiki/Wiki#cite_ref-49
# https://web.archive.org/web/20070810213702/http://wikinodes.wiki.taoriver.net/moin.fcg/FrequentlyAskedQuestions
# http://wikinodes.wiki.taoriver.net/moin.fcg/FrequentlyAskedQuestions
# #cite_ref-50
# https://en.wikipedia.org/wiki/Wiki#cite_ref-50
# https://web.archive.org/web/20110515005430/https://uhra.herts.ac.uk/dspace/handle/2299/3672
# https://uhra.herts.ac.uk/dspace/handle/2299/3672
# /wiki/Help:CS1_errors#missing_periodical
# https://en.wikipedia.org/wiki/Help:CS1_errors#missing_periodical
# #cite_ref-51
# https://en.wikipedia.org/wiki/Wiki#cite_ref-51
# http://nitens.org/docs/wikidyn.pdf
# https://web.archive.org/web/20171011105517/http://nitens.org/docs/wikidyn.pdf
# /wiki/Help:CS1_errors#missing_periodical
# https://en.wikipedia.org/wiki/Help:CS1_errors#missing_periodical
# #cite_ref-52
# https://en.wikipedia.org/wiki/Wiki#cite_ref-52
# https://web.archive.org/web/20120616204038/http://epubs.surrey.ac.uk/1565/1/fulltext.pdf#
# http://epubs.surrey.ac.uk:80/1565/1/fulltext.pdf
# /wiki/Help:CS1_errors#missing_periodical
# https://en.wikipedia.org/wiki/Help:CS1_errors#missing_periodical
# #cite_ref-53
# https://en.wikipedia.org/wiki/Wiki#cite_ref-53
# http://summit.atlassian.com/
# https://web.archive.org/web/20110613081406/http://summit.atlassian.com/
# #cite_ref-54
# https://en.wikipedia.org/wiki/Wiki#cite_ref-54
# http://semantic-mediawiki.org/wiki/SMWCon
# https://web.archive.org/web/20110714183910/http://semantic-mediawiki.org/wiki/SMWCon
# #cite_ref-55
# https://en.wikipedia.org/wiki/Wiki#cite_ref-55
# http://tiki.org/TikiFest
# https://web.archive.org/web/20110630070137/http://tiki.org/TikiFest
# #cite_ref-56
# https://en.wikipedia.org/wiki/Wiki#cite_ref-56
# http://wiki.regiowiki.eu/Main_Page
# https://web.archive.org/web/20090813101324/http://wiki.regiowiki.eu/Main_Page
# #cite_ref-57
# https://en.wikipedia.org/wiki/Wiki#cite_ref-57
# http://www.conservapedia.com/Conservapedia:Commandments
# https://web.archive.org/web/20101022014810/http://conservapedia.com/Conservapedia:Commandments
# #cite_ref-58
# https://en.wikipedia.org/wiki/Wiki#cite_ref-58
# /wiki/Help:CS1_errors#citation_missing_title
# https://en.wikipedia.org/wiki/Help:CS1_errors#citation_missing_title
# #cite_ref-59
# https://en.wikipedia.org/wiki/Wiki#cite_ref-59
# http://works.bepress.com/cgi/viewcontent.cgi?article=1000&context=sarah_oh
# https://web.archive.org/web/20140106040705/http://works.bepress.com/cgi/viewcontent.cgi?article=1000&context=sarah_oh
# /wiki/Help:CS1_errors#missing_periodical
# https://en.wikipedia.org/wiki/Help:CS1_errors#missing_periodical
# #cite_ref-60
# https://en.wikipedia.org/wiki/Wiki#cite_ref-60
# /wiki/SSRN_(identifier)
# https://en.wikipedia.org/wiki/SSRN_(identifier)
# //ssrn.com/abstract=916529
# https://ssrn.com/abstract=916529
# #cite_ref-61
# https://en.wikipedia.org/wiki/Wiki#cite_ref-61
# http://heinonline.org/HOL/LandingPage?collection=journals&handle=hein.journals/manintpr179&div=31&id=&page=
# https://web.archive.org/web/20160304044437/http://heinonline.org/HOL/LandingPage?collection=journals&handle=hein.journals%2Fmanintpr179&div=31&id=&page=
# /wiki/Springer_Science%2BBusiness_Media
# https://en.wikipedia.org/wiki/Springer_Science%2BBusiness_Media
# /wiki/ISBN_(identifier)
# https://en.wikipedia.org/wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-3-540-35150-4
# https://en.wikipedia.org/wiki/Special:BookSources/978-3-540-35150-4
# https://archive.org/details/isbn_9780201714999
# /wiki/Addison%E2%80%93Wesley
# https://en.wikipedia.org/wiki/Addison%E2%80%93Wesley
# /wiki/ISBN_(identifier)
# https://en.wikipedia.org/wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-201-71499-9
# https://en.wikipedia.org/wiki/Special:BookSources/978-0-201-71499-9
# https://archive.org/details/wikipatternsapra00made
# /wiki/John_Wiley_%26_Sons
# https://en.wikipedia.org/wiki/John_Wiley_%26_Sons
# /wiki/ISBN_(identifier)
# https://en.wikipedia.org/wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-0-470-22362-8
# https://en.wikipedia.org/wiki/Special:BookSources/978-0-470-22362-8
# /wiki/Mass_Collaboration
# https://en.wikipedia.org/wiki/Mass_Collaboration
# /wiki/ISBN_(identifier)
# https://en.wikipedia.org/wiki/ISBN_(identifier)
# /wiki/Special:BookSources/978-1-59184-193-7
# https://en.wikipedia.org/wiki/Special:BookSources/978-1-59184-193-7
# /wiki/File:En-Wiki2.ogg
# https://en.wikipedia.org/wiki/File:En-Wiki2.ogg
# /wiki/Wikipedia:Media_help
# https://en.wikipedia.org/wiki/Wikipedia:Media_help
# /wiki/Wikipedia:Spoken_articles
# https://en.wikipedia.org/wiki/Wikipedia:Spoken_articles
# /wiki/Wikipedia:Wikimedia_sister_projects
# https://en.wikipedia.org/wiki/Wikipedia:Wikimedia_sister_projects
# https://en.wiktionary.org/wiki/wiki
# https://commons.wikimedia.org/wiki/category:Wiki_software
# https://en.wikinews.org/wiki/Special:Search/Wiki
# https://en.wikiversity.org/wiki/Special:Search/Wiki
# https://www.wikidata.org/wiki/Q171
# https://www.mediawiki.org/wiki/wiki
# https://curlie.org/Computers/Software/Groupware/Wiki/
# /wiki/Curlie
# https://en.wikipedia.org/wiki/Curlie
# http://www.artima.com/intv/wiki.html
# /wiki/Ward_Cunningham
# https://en.wikipedia.org/wiki/Ward_Cunningham
# http://wikiindex.org/Welcome
# https://wikiapiary.com
# http://www.wikimatrix.org/
# https://github.com/WikiTeam/wikiteam
# /wiki/Archive_Team
# https://en.wikipedia.org/wiki/Archive_Team
# https://web.archive.org/web/20110709101821/http://www.ucop.edu/tltc/news/2006/04/wiki.html
# /wiki/University_of_California
# https://en.wikipedia.org/wiki/University_of_California
# http://c2.com/doc/etymology.html
# /wiki/Template:Wikis
# https://en.wikipedia.org/wiki/Template:Wikis
# /wiki/Template_talk:Wikis
# https://en.wikipedia.org/wiki/Template_talk:Wikis
# https://en.wikipedia.org/w/index.php?title=Template:Wikis&action=edit
# None
# /wiki/Personal_wiki
# https://en.wikipedia.org/wiki/Personal_wiki
# /wiki/List_of_medical_wikis
# https://en.wikipedia.org/wiki/List_of_medical_wikis
# /wiki/Semantic_wiki
# https://en.wikipedia.org/wiki/Semantic_wiki
# /wiki/Wiki_hosting_service
# https://en.wikipedia.org/wiki/Wiki_hosting_service
# /wiki/Wiki_software
# https://en.wikipedia.org/wiki/Wiki_software
# /wiki/Interwiki_links
# https://en.wikipedia.org/wiki/Interwiki_links
# /wiki/List_of_wikis
# https://en.wikipedia.org/wiki/List_of_wikis
# /wiki/List_of_wiki_software
# https://en.wikipedia.org/wiki/List_of_wiki_software
# /wiki/Comparison_of_wiki_software
# https://en.wikipedia.org/wiki/Comparison_of_wiki_software
# /wiki/Comparison_of_wiki_hosting_services
# https://en.wikipedia.org/wiki/Comparison_of_wiki_hosting_services
# /wiki/History_of_wikis
# https://en.wikipedia.org/wiki/History_of_wikis
# /wiki/Creole_(markup)
# https://en.wikipedia.org/wiki/Creole_(markup)
# /wiki/Template:Wiki_software
# https://en.wikipedia.org/wiki/Template:Wiki_software
# /wiki/Template_talk:Wiki_software
# https://en.wikipedia.org/wiki/Template_talk:Wiki_software
# https://en.wikipedia.org/w/index.php?title=Template:Wiki_software&action=edit
# /wiki/Wiki_software
# https://en.wikipedia.org/wiki/Wiki_software
# /wiki/.NET_Framework
# https://en.wikipedia.org/wiki/.NET_Framework
# /wiki/FlexWiki
# https://en.wikipedia.org/wiki/FlexWiki
# /wiki/Microsoft_SharePoint
# https://en.wikipedia.org/wiki/Microsoft_SharePoint
# /wiki/Java_(programming_language)
# https://en.wikipedia.org/wiki/Java_(programming_language)
# /wiki/Confluence_(software)
# https://en.wikipedia.org/wiki/Confluence_(software)
# /wiki/Jive_(software)
# https://en.wikipedia.org/wiki/Jive_(software)
# /wiki/Traction_TeamPage
# https://en.wikipedia.org/wiki/Traction_TeamPage
# /wiki/XWiki
# https://en.wikipedia.org/wiki/XWiki
# /wiki/JavaScript
# https://en.wikipedia.org/wiki/JavaScript
# /wiki/Nuclino
# https://en.wikipedia.org/wiki/Nuclino
# /wiki/TiddlyWiki
# https://en.wikipedia.org/wiki/TiddlyWiki
# /wiki/Wiki.js
# https://en.wikipedia.org/wiki/Wiki.js
# /wiki/Perl
# https://en.wikipedia.org/wiki/Perl
# /wiki/Foswiki
# https://en.wikipedia.org/wiki/Foswiki
# /wiki/Ikiwiki
# https://en.wikipedia.org/wiki/Ikiwiki
# /wiki/TWiki
# https://en.wikipedia.org/wiki/TWiki
# /wiki/UseModWiki
# https://en.wikipedia.org/wiki/UseModWiki
# /wiki/WikiWikiWeb
# https://en.wikipedia.org/wiki/WikiWikiWeb
# /wiki/PHP
# https://en.wikipedia.org/wiki/PHP
# /wiki/DokuWiki
# https://en.wikipedia.org/wiki/DokuWiki
# /wiki/MediaWiki
# https://en.wikipedia.org/wiki/MediaWiki
# /wiki/MindTouch
# https://en.wikipedia.org/wiki/MindTouch
# /wiki/PhpWiki
# https://en.wikipedia.org/wiki/PhpWiki
# /wiki/Phabricator
# https://en.wikipedia.org/wiki/Phabricator
# /wiki/PmWiki
# https://en.wikipedia.org/wiki/PmWiki
# /wiki/Tiki_Wiki_CMS_Groupware
# https://en.wikipedia.org/wiki/Tiki_Wiki_CMS_Groupware
# /wiki/PukiWiki
# https://en.wikipedia.org/wiki/PukiWiki
# /wiki/Python_(programming_language)
# https://en.wikipedia.org/wiki/Python_(programming_language)
# /wiki/Apache_Allura
# https://en.wikipedia.org/wiki/Apache_Allura
# /wiki/Apache_Bloodhound
# https://en.wikipedia.org/wiki/Apache_Bloodhound
# /wiki/Kallithea_(software)
# https://en.wikipedia.org/wiki/Kallithea_(software)
# /wiki/Kuma_(software)
# https://en.wikipedia.org/wiki/Kuma_(software)
# /wiki/MoinMoin
# https://en.wikipedia.org/wiki/MoinMoin
# /wiki/Trac
# ...
# https://en.wikipedia.org/wiki/Data_conferencing
# /wiki/Instant_messaging
# https://en.wikipedia.org/wiki/Instant_messaging
# /wiki/Internet_Relay_Chat
# https://en.wikipedia.org/wiki/Internet_Relay_Chat
# /wiki/LAN_messenger
# https://en.wikipedia.org/wiki/LAN_messenger
# /wiki/Talker
# https://en.wikipedia.org/wiki/Talker
# /wiki/Videoconferencing
# https://en.wikipedia.org/wiki/Videoconferencing
# /wiki/Voice_over_IP
# https://en.wikipedia.org/wiki/Voice_over_IP
# /wiki/Voice_chat_in_online_gaming
# https://en.wikipedia.org/wiki/Voice_chat_in_online_gaming
# /wiki/Web_chat
# https://en.wikipedia.org/wiki/Web_chat
# /wiki/Web_conferencing
# https://en.wikipedia.org/wiki/Web_conferencing
# /wiki/Blog
# https://en.wikipedia.org/wiki/Blog
# /wiki/Microblogging
# https://en.wikipedia.org/wiki/Microblogging
# None
# /wiki/Help:Authority_control
# https://en.wikipedia.org/wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q171#identifiers
# /wiki/GND_(identifier)
# https://en.wikipedia.org/wiki/GND_(identifier)
# https://d-nb.info/gnd/4806885-8
# /wiki/LCCN_(identifier)
# https://en.wikipedia.org/wiki/LCCN_(identifier)
# https://id.loc.gov/authorities/subjects/sh00004800
# https://en.wikipedia.org/w/index.php?title=Wiki&oldid=991544914
# /wiki/Help:Category
# https://en.wikipedia.org/wiki/Help:Category
# /wiki/Category:Wikis
# https://en.wikipedia.org/wiki/Category:Wikis
# /wiki/Category:Hawaiian_words_and_phrases
# https://en.wikipedia.org/wiki/Category:Hawaiian_words_and_phrases
# /wiki/Category:Hypertext
# https://en.wikipedia.org/wiki/Category:Hypertext
# /wiki/Category:Self-organization
# https://en.wikipedia.org/wiki/Category:Self-organization
# /wiki/Category:Social_information_processing
# https://en.wikipedia.org/wiki/Category:Social_information_processing
# /wiki/Category:CS1_maint:_archived_copy_as_title
# https://en.wikipedia.org/wiki/Category:CS1_maint:_archived_copy_as_title
# /wiki/Category:CS1_errors:_missing_periodical
# https://en.wikipedia.org/wiki/Category:CS1_errors:_missing_periodical
# /wiki/Category:Pages_containing_links_to_subscription-only_content
# https://en.wikipedia.org/wiki/Category:Pages_containing_links_to_subscription-only_content
# /wiki/Category:Webarchive_template_wayback_links
# https://en.wikipedia.org/wiki/Category:Webarchive_template_wayback_links
# /wiki/Category:Pages_with_citations_lacking_titles
# https://en.wikipedia.org/wiki/Category:Pages_with_citations_lacking_titles
# /wiki/Category:CS1:_long_volume_value
# https://en.wikipedia.org/wiki/Category:CS1:_long_volume_value
# /wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# https://en.wikipedia.org/wiki/Category:Wikipedia_indefinitely_semi-protected_pages
# /wiki/Category:Wikipedia_indefinitely_move-protected_pages
# https://en.wikipedia.org/wiki/Category:Wikipedia_indefinitely_move-protected_pages
# /wiki/Category:Articles_with_short_description
# https://en.wikipedia.org/wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_matches_Wikidata
# https://en.wikipedia.org/wiki/Category:Short_description_matches_Wikidata
# /wiki/Category:Use_mdy_dates_from_July_2019
# https://en.wikipedia.org/wiki/Category:Use_mdy_dates_from_July_2019
# /wiki/Category:Articles_with_hAudio_microformats
# https://en.wikipedia.org/wiki/Category:Articles_with_hAudio_microformats
# /wiki/Category:Pages_including_recorded_pronunciations
# https://en.wikipedia.org/wiki/Category:Pages_including_recorded_pronunciations
# /wiki/Category:Articles_needing_additional_references_from_March_2017
# https://en.wikipedia.org/wiki/Category:Articles_needing_additional_references_from_March_2017
# /wiki/Category:All_articles_needing_additional_references
# https://en.wikipedia.org/wiki/Category:All_articles_needing_additional_references
# /wiki/Category:All_articles_needing_examples
# https://en.wikipedia.org/wiki/Category:All_articles_needing_examples
# /wiki/Category:Articles_needing_examples_from_August_2018
# https://en.wikipedia.org/wiki/Category:Articles_needing_examples_from_August_2018
# /wiki/Category:All_articles_with_unsourced_statements
# https://en.wikipedia.org/wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_July_2013
# https://en.wikipedia.org/wiki/Category:Articles_with_unsourced_statements_from_July_2013
# /wiki/Category:Articles_with_unsourced_statements_from_April_2020
# https://en.wikipedia.org/wiki/Category:Articles_with_unsourced_statements_from_April_2020
# /wiki/Category:All_articles_lacking_reliable_references
# https://en.wikipedia.org/wiki/Category:All_articles_lacking_reliable_references
# /wiki/Category:Articles_lacking_reliable_references_from_July_2013
# https://en.wikipedia.org/wiki/Category:Articles_lacking_reliable_references_from_July_2013
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_July_2013
# https://en.wikipedia.org/wiki/Category:Wikipedia_articles_in_need_of_updating_from_July_2013
# /wiki/Category:All_Wikipedia_articles_in_need_of_updating
# https://en.wikipedia.org/wiki/Category:All_Wikipedia_articles_in_need_of_updating
# /wiki/Category:Spoken_articles
# https://en.wikipedia.org/wiki/Category:Spoken_articles
# /wiki/Category:Articles_with_Curlie_links
# https://en.wikipedia.org/wiki/Category:Articles_with_Curlie_links
# /wiki/Category:Wikipedia_articles_with_GND_identifiers
# https://en.wikipedia.org/wiki/Category:Wikipedia_articles_with_GND_identifiers
# /wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# https://en.wikipedia.org/wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# /wiki/Category:Articles_containing_video_clips
# https://en.wikipedia.org/wiki/Category:Articles_containing_video_clips
# /wiki/Special:MyTalk
# https://en.wikipedia.org/wiki/Special:MyTalk
# /wiki/Special:MyContributions
# https://en.wikipedia.org/wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Wiki
# https://en.wikipedia.org/w/index.php?title=Special:CreateAccount&returnto=Wiki
# /w/index.php?title=Special:UserLogin&returnto=Wiki
# https://en.wikipedia.org/w/index.php?title=Special:UserLogin&returnto=Wiki
# /wiki/Wiki
# https://en.wikipedia.org/wiki/Wiki
# /wiki/Talk:Wiki
# https://en.wikipedia.org/wiki/Talk:Wiki
# /wiki/Wiki
# https://en.wikipedia.org/wiki/Wiki
# /w/index.php?title=Wiki&action=edit
# https://en.wikipedia.org/w/index.php?title=Wiki&action=edit
# /w/index.php?title=Wiki&action=history
# https://en.wikipedia.org/w/index.php?title=Wiki&action=history
# /wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# /wiki/Main_Page
# https://en.wikipedia.org/wiki/Main_Page
# /wiki/Wikipedia:Contents
# https://en.wikipedia.org/wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# https://en.wikipedia.org/wiki/Portal:Current_events
# /wiki/Special:Random
# https://en.wikipedia.org/wiki/Special:Random
# /wiki/Wikipedia:About
# https://en.wikipedia.org/wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# https://en.wikipedia.org/wiki/Help:Contents
# /wiki/Help:Introduction
# https://en.wikipedia.org/wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# https://en.wikipedia.org/wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# https://en.wikipedia.org/wiki/Special:RecentChanges
# /wiki/Wikipedia:File_Upload_Wizard
# https://en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:WhatLinksHere/Wiki
# https://en.wikipedia.org/wiki/Special:WhatLinksHere/Wiki
# /wiki/Special:RecentChangesLinked/Wiki
# https://en.wikipedia.org/wiki/Special:RecentChangesLinked/Wiki
# /wiki/Wikipedia:File_Upload_Wizard
# https://en.wikipedia.org/wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# https://en.wikipedia.org/wiki/Special:SpecialPages
# /w/index.php?title=Wiki&oldid=991544914
# https://en.wikipedia.org/w/index.php?title=Wiki&oldid=991544914
# /w/index.php?title=Wiki&action=info
# https://en.wikipedia.org/w/index.php?title=Wiki&action=info
# /w/index.php?title=Special:CiteThisPage&page=Wiki&id=991544914&wpFormIdentifier=titleform
# https://en.wikipedia.org/w/index.php?title=Special:CiteThisPage&page=Wiki&id=991544914&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q171
# /w/index.php?title=Special:DownloadAsPdf&page=Wiki&action=show-download-screen
# https://en.wikipedia.org/w/index.php?title=Special:DownloadAsPdf&page=Wiki&action=show-download-screen
# /w/index.php?title=Wiki&printable=yes
# https://en.wikipedia.org/w/index.php?title=Wiki&printable=yes
# https://commons.wikimedia.org/wiki/Category:Wiki
# https://meta.wikimedia.org/wiki/Wiki
# https://af.wikipedia.org/wiki/Wiki
# https://als.wikipedia.org/wiki/Wiki
# https://ar.wikipedia.org/wiki/%D9%88%D9%8A%D9%83%D9%8A
# https://an.wikipedia.org/wiki/Wiki
# https://as.wikipedia.org/wiki/%E0%A7%B1%E0%A6%BF%E0%A6%95%E0%A6%BF
# https://ast.wikipedia.org/wiki/Wiki
# https://az.wikipedia.org/wiki/Viki
# https://bm.wikipedia.org/wiki/Wiki
# https://bn.wikipedia.org/wiki/%E0%A6%89%E0%A6%87%E0%A6%95%E0%A6%BF
# https://bjn.wikipedia.org/wiki/Wiki
# https://zh-min-nan.wikipedia.org/wiki/Wiki
# https://ba.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://be.wikipedia.org/wiki/%D0%92%D1%96%D0%BA%D1%96
# https://be-tarask.wikipedia.org/wiki/%D0%92%D1%96%D0%BA%D1%96
# https://bg.wikipedia.org/wiki/%D0%A3%D0%B8%D0%BA%D0%B8
# https://bar.wikipedia.org/wiki/Wiki
# https://bs.wikipedia.org/wiki/Wiki
# https://br.wikipedia.org/wiki/Wiki
# https://bxr.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://ca.wikipedia.org/wiki/Wiki
# https://cv.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://ceb.wikipedia.org/wiki/Wiki
# https://cs.wikipedia.org/wiki/Wiki
# https://co.wikipedia.org/wiki/Wiki
# https://cy.wikipedia.org/wiki/Wici
# https://da.wikipedia.org/wiki/Wiki
# https://de.wikipedia.org/wiki/Wiki
# https://et.wikipedia.org/wiki/Viki
# https://el.wikipedia.org/wiki/Wiki
# https://es.wikipedia.org/wiki/Wiki
# https://eo.wikipedia.org/wiki/Vikio
# https://eu.wikipedia.org/wiki/Wiki
# https://fa.wikipedia.org/wiki/%D9%88%DB%8C%DA%A9%DB%8C
# https://fo.wikipedia.org/wiki/Wiki
# https://fr.wikipedia.org/wiki/Wiki
# https://fur.wikipedia.org/wiki/Wiki
# https://ga.wikipedia.org/wiki/Vic%C3%AD
# https://gl.wikipedia.org/wiki/Wiki
# https://inh.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://xal.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://ko.wikipedia.org/wiki/%EC%9C%84%ED%82%A4
# https://hy.wikipedia.org/wiki/%D5%8E%D5%AB%D6%84%D5%AB
# https://hi.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%95%E0%A4%BF
# https://hr.wikipedia.org/wiki/Wiki
# https://ig.wikipedia.org/wiki/Wiki
# https://ilo.wikipedia.org/wiki/Wiki
# https://bpy.wikipedia.org/wiki/%E0%A6%89%E0%A6%87%E0%A6%95%E0%A6%BF
# https://id.wikipedia.org/wiki/Wiki
# https://ia.wikipedia.org/wiki/Wiki
# https://iu.wikipedia.org/wiki/%E1%90%85%E1%90%83%E1%91%AD
# https://is.wikipedia.org/wiki/Wiki
# https://it.wikipedia.org/wiki/Wiki
# https://he.wikipedia.org/wiki/%D7%95%D7%99%D7%A7%D7%99
# https://jv.wikipedia.org/wiki/Wiki
# https://kn.wikipedia.org/wiki/%E0%B2%B5%E0%B2%BF%E0%B2%95%E0%B2%BF
# https://ka.wikipedia.org/wiki/Wiki
# https://kk.wikipedia.org/wiki/%D0%A3%D0%B8%D0%BA%D0%B8
# https://sw.wikipedia.org/wiki/Wiki
# https://gcr.wikipedia.org/wiki/Wiki
# https://ky.wikipedia.org/wiki/%D0%A3%D0%B8%D0%BA%D0%B8
# https://la.wikipedia.org/wiki/Vici
# https://lv.wikipedia.org/wiki/Vikivietne
# https://lb.wikipedia.org/wiki/Wiki
# https://lt.wikipedia.org/wiki/Wiki
# https://li.wikipedia.org/wiki/Wiki
# https://lfn.wikipedia.org/wiki/Vici
# https://jbo.wikipedia.org/wiki/uitki
# https://lmo.wikipedia.org/wiki/Wiki
# https://hu.wikipedia.org/wiki/Wiki
# https://mk.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://mg.wikipedia.org/wiki/Wiki
# https://ml.wikipedia.org/wiki/%E0%B4%B5%E0%B4%BF%E0%B4%95%E0%B5%8D%E0%B4%95%E0%B4%BF
# https://mt.wikipedia.org/wiki/Wiki
# https://mr.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%95%E0%A5%80
# https://xmf.wikipedia.org/wiki/%E1%83%95%E1%83%98%E1%83%99%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%88%D9%8A%D9%83%D9%89
# https://ms.wikipedia.org/wiki/Wiki
# https://min.wikipedia.org/wiki/Wiki
# https://mn.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://my.wikipedia.org/wiki/%E1%80%9D%E1%80%AE%E1%80%80%E1%80%AE
# https://nah.wikipedia.org/wiki/Huiqui
# https://fj.wikipedia.org/wiki/Wiki
# https://nl.wikipedia.org/wiki/Wiki
# https://nds-nl.wikipedia.org/wiki/Wiki
# https://ne.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%95%E0%A4%BF
# https://ja.wikipedia.org/wiki/%E3%82%A6%E3%82%A3%E3%82%AD
# https://no.wikipedia.org/wiki/Wiki
# https://nn.wikipedia.org/wiki/Wiki
# https://nrm.wikipedia.org/wiki/Ouitchi
# https://oc.wikipedia.org/wiki/Wiki
# https://pa.wikipedia.org/wiki/%E0%A8%B5%E0%A8%BF%E0%A8%95%E0%A9%80
# https://pag.wikipedia.org/wiki/Wiki
# https://nds.wikipedia.org/wiki/Wiki
# https://pl.wikipedia.org/wiki/Wiki
# https://pnt.wikipedia.org/wiki/%CE%92%CE%B9%CE%BA%CE%B9
# https://pt.wikipedia.org/wiki/Wiki
# https://ro.wikipedia.org/wiki/Wiki
# https://qu.wikipedia.org/wiki/Wiki
# https://rue.wikipedia.org/wiki/%D0%92%D1%96%D0%BA%D1%96
# https://ru.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://sa.wikipedia.org/wiki/%E0%A4%B5%E0%A4%BF%E0%A4%95%E0%A4%BF%E0%A4%83
# https://sc.wikipedia.org/wiki/Wiki
# https://sco.wikipedia.org/wiki/Wiki
# https://sq.wikipedia.org/wiki/Wiki
# https://scn.wikipedia.org/wiki/Wiki
# https://si.wikipedia.org/wiki/%E0%B7%80%E0%B7%92%E0%B6%9A%E0%B7%92
# https://simple.wikipedia.org/wiki/Wiki
# https://sk.wikipedia.org/wiki/Wiki
# https://sl.wikipedia.org/wiki/Wiki
# https://so.wikipedia.org/wiki/Wiki
# https://ckb.wikipedia.org/wiki/%D9%88%DB%8C%DA%A9%DB%8C
# https://sr.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://sh.wikipedia.org/wiki/Wiki
# https://su.wikipedia.org/wiki/Wiki
# https://fi.wikipedia.org/wiki/Wiki
# https://sv.wikipedia.org/wiki/Wiki
# https://tl.wikipedia.org/wiki/Wiki
# https://ta.wikipedia.org/wiki/%E0%AE%B5%E0%AE%BF%E0%AE%95%E0%AF%8D%E0%AE%95%E0%AE%BF
# https://kab.wikipedia.org/wiki/Wiki
# https://tt.wikipedia.org/wiki/Wiki
# https://shn.wikipedia.org/wiki/%E1%80%9D%E1%80%AE%E1%82%87%E1%81%B6%E1%80%AE%E1%82%87
# https://te.wikipedia.org/wiki/%E0%B0%B5%E0%B0%BF%E0%B0%95%E0%B1%80
# https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%81%E0%B8%B4
# https://tg.wikipedia.org/wiki/%D0%92%D0%B8%D0%BA%D0%B8
# https://tr.wikipedia.org/wiki/Viki
# https://uk.wikipedia.org/wiki/%D0%92%D1%96%D0%BA%D1%96
# https://ur.wikipedia.org/wiki/%D9%88%DB%8C%DA%A9%DB%8C
# https://vi.wikipedia.org/wiki/Wiki
# https://fiu-vro.wikipedia.org/wiki/Viki
# https://zh-classical.wikipedia.org/wiki/%E5%85%B1%E7%AD%86
# https://war.wikipedia.org/wiki/Wiki
# https://wuu.wikipedia.org/wiki/Wiki
# https://yi.wikipedia.org/wiki/%D7%95%D7%95%D7%99%D7%A7%D7%99
# https://yo.wikipedia.org/wiki/Wiki
# https://zh-yue.wikipedia.org/wiki/Wiki
# https://diq.wikipedia.org/wiki/Wiki
# https://bat-smg.wikipedia.org/wiki/Wiki
# https://zh.wikipedia.org/wiki/Wiki
# https://www.wikidata.org/wiki/Special:EntityPage/Q171#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# https://creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# https://foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# https://foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# https://en.wikipedia.org/wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# https://en.wikipedia.org/wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=Wiki&mobileaction=toggle_view_mobile
# https://en.m.wikipedia.org/w/index.php?title=Wiki&mobileaction=toggle_view_mobile
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# Here, we now have the start of a very simple crawler.
# It finds the hyperlinks in the web page and builds usable urls with them.
# If there’s already an http at the start, we don’t have to do anything.
# If the link starts with a hashtag, then the link is referring to an element on the current page so that will not get us anywhere.
# For anything else we use url join to attach the base url to the link and voila we have links that we can feed into requests and get more data.
#
# ---
#
# We are still assuming the data we’re after is in a text form but there’s so much more.
#
# For imaging task we might want to scrape pictures from the internet.

# %%
from PIL import Image

# %% [markdown]
# We’ll import the module from PIL so that we can display what we get from the web.
#
# ---

# %%
url = "http://media.vam.ac.uk/media/thira/collection_images/2006BB/2006BB5716.jpg"
img_data = requests.get(url, stream = True).raw
print(img_data.data)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x01,\x01,\x00\x00\xff\xfe\x00\x0ePicture 2128\xff\xed,BPhotoshop 3.0\x008BIM\x04%\x00\x00\x00\x00\x00\x10\xeb\xc5q&\x98\xe5\xcf\xc8\xafi&-u>\x9d\xe08BIM\x04:\x00\x00\x00\x00\x00\x93\x00\x00\x00\x10\x00\x00\x00\x01\x00\x00\x00\x00\x00\x0bprintOutput\x00\x00\x00\x05\x00\x00\x00\x00ClrSenum\x00\x00\x00\x00ClrS\x00\x00\x00\x00RGBC\x00\x00\x00\x00Inteenum\x00\x00\x00\x00Inte\x00\x00\x00\x00Clrm\x00\x00\x00\x00MpBlbool\x01\x00\x00\x00\x0fprintSixteenBitbool\x00\x00\x00\x00\x0bprinterNameTEXT\x00\x00\x00\x01\x00\x00\x008BIM\x04;\x00\x00\x00\x00\x01\xb2\x00\x00\x00\x10\x00\x00\x00\x01\x00\x00\x00\x00\x00\x12printOutputOptions\x00\x00\x00\x12\x00\x00\x00\x00Cptnbool\x00\x00\x00\x00\x00Clbrbool\x00\x00\x00\x00\x00RgsMbool\x00\x00\x00\x00\x00CrnCbool\x00\x00\x00\x00\x00CntCbool\x00\x00\x00\x00\x00Lblsbool\x00\x00\x00\x00\x00Ngtvbool\x00\x00\x00\x00\x00EmlDbool\x00\x00\x00\x00\x00Intrbool\x00\x00\x00\x00\x00BckgObjc\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00RGBC\x00\x00\x00\x03\x00\x00\x00\x00Rd  doub@o\xe0\x00\x00\x00\x00\x00\x00\x00\x00\x00Grn doub@o\xe0\x00\x00\x00\x00\x00\x00\x00\x00\x00Bl  doub@o\xe0\x00\x00\x00\x00\x00\x00\x00\x00\x00BrdTUntF#Rlt\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00Bld UntF#Rlt\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00RsltUntF#Pxl@r\xc0\x00\x00\x00\x00\x00\x00\x00\x00\nvectorDatabool\x01\x00\x00\x00\x00PgPsenum\x00\x00\x00\x00PgPs\x00\x00\x00\x00PgPC\x00\x00\x00\x00LeftUntF#Rlt\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00Top UntF#Rlt\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00Scl UntF#Prc@Y\x00\x00\x00\x00\x00\x008BIM\x03\xed\x00\x00\x00\x00\x00\x10\x01,\x00\x00\x00\x01\x00\x02\x01,\x00\x00\x00\x01\x00\x028BIM\x04&\x00\x00\x00\x00\x00\x0e\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00?\x80\x00\x008BIM\x04\r\x00\x00\x00\x00\x00\x04\xff\xff\xff\xc48BIM\x04\x19\x00\x00\x00\x00\x00\x04\x00\x00\x00\x1e8BIM\x03\xf3\x00\x00\x00\x00\x00\t\x00\x00\x00\x00\x00\x00\x00\x00\x01\x008BIM\'\x10\x00\x00\x00\x00\x00\n\x00\x01\x00\x00\x00\x00\x00\x00\x00\x028BIM\x03\xf5\x00\x00\x00\x00\x00H\x00/ff\x00\x01\x00lff\x00\x06\x00\x00\x00\x00\x00\x01\x00/ff\x00\x01\x00\xa1\x99\x9a\x00\x06\x00\x00\x00\x00\x00\x01\x002\x00\x00\x00\x01\x00Z\x00\x00\x00\x06\x00\x00\x00\x00\x00\x01\x005\x00\x00\x00\x01\x00-\x00\x00\x00\x06\x00\x00\x00\x00\x00\x018BIM\x03\xf8\x00\x00\x00\x00\x00p8BIM\x04\x08\x00\x00\x00\x00\x00\x10\x00\x00\x00\x01\x00\x00\x02@\x00\x00\x02@\x00\x00\x00\x008BIM\x04\x1e\x00\x00\x00\x00\x00\x04\x00\x00\x00\x008BIM\x04\x1a\x00\x00\x00\x00\x03I\x00\x00\x00\x06\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0e\xd5\x00\x00\x141\x00\x00\x00\n\x002\x000\x000\x006\x00B\x00B\x005\x007\x001\x006\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x141\x00\x00\x0e\xd5\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00null\x00\x00\x00\x02\x00\x00\x00\x06boundsObjc\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00Rct1\x00\x00\x00\x04\x00\x00\x00\x00Top long\x00\x00\x00\x00\x00\x00\x00\x00Leftlong\x00\x00\x00\x00\x00\x00\x00\x00Btomlong\x00\x00\x0e\xd5\x00\x00\x00\x00Rghtlong\x00\x00\x141\x00\x00\x00\x06slicesVlLs\x00\x00\x00\x01Objc\x00\x00\x00\x01\x00\x00\x00\x00\x00\x05slice\x00\x00\x00\x12\x00\x00\x00\x07sliceIDlong\x00\x00\x00\x00\x00\x00\x00\x07groupIDlong\x00\x00\x00\x00\x00\x00\x00\x06originenum\x00\x00\x00\x0cESliceOrigin\x00\x00\x00\rau ...

# %% [markdown]
# Then, just like before, we use either the get or post method to fetch the raw data this time. We need to include the stream argument to keep the connection open while the data is being downloaded.
#
# ---
#
# If we print the data, it doesn’t make much sense. To us at least.

# %%
img_data = requests.get(url, stream = True).raw
display(Image.open(img_data))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x564 at 0x11071EDD0>

# %% [markdown]
# Load it into the image and we see a pretty picture.
#
# ---
#
# You’ll learn in other sessions how to use and manipulate image data.
#
# But now you can go and exercise your skills at retrieving it from the web.
